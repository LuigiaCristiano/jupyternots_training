# %% [markdown]
# Convert different formats of the DataCite xml structure to JSON, BibTex or CSV

# %% [markdown]
# Using the Bolognese toolbox developed at MIT

# %% [markdown]
# Bolognese a Ruby library for conversion of DOI Metadata ; https://github.com/datacite/bolognese

# %% [markdown]
# bolognese https://doi.org/10.1029/2020jb019770

# %%
{
  "@context": "http://schema.org",
  "@type": "ScholarlyArticle",
  "@id": "https://doi.org/10.1029/2020jb019770",
  "url": "https://onlinelibrary.wiley.com/doi/10.1029/2020JB019770",
  "additionalType": "JournalArticle",
  "name": "Temporal Modulation of the Local Microseism in the North Sea",
  "author": [
    {
      "name": "D. Becker",
      "givenName": "D.",
      "familyName": "Becker",
      "affiliation": {
        "@type": "Organization",
        "name": "Institute of Geophysics, Centre for Earth System Research and Sustainability (CEN) Universit??t Hamburg  Hamburg Germany"
      },
      "@type": "Person",
      "@id": "https://orcid.org/0000-0002-9414-2135"
    },
    {
      "name": "L. Cristiano",
      "givenName": "L.",
      "familyName": "Cristiano",
      "affiliation": [
        {
          "@type": "Organization",
          "name": "Department of Geosciences Christian???Albrechts???Universit??t zu Kiel  Kiel Germany"
        },
        {
          "@type": "Organization",
          "name": "Now at GFZ German Research Centre for Geosciences  Potsdam Germany"
        }
      ],
      "@type": "Person"
    },
    {
      "name": "J. Peikert",
      "givenName": "J.",
      "familyName": "Peikert",
      "affiliation": {
        "@type": "Organization",
        "name": "Department of Geosciences Christian???Albrechts???Universit??t zu Kiel  Kiel Germany"
      },
      "@type": "Person"
    },
    {
      "name": "T. Kruse",
      "givenName": "T.",
      "familyName": "Kruse",
      "affiliation": {
        "@type": "Organization",
        "name": "Department of Geosciences Christian???Albrechts???Universit??t zu Kiel  Kiel Germany"
      },
      "@type": "Person"
    },
    {
      "name": "F. Dethof",
      "givenName": "F.",
      "familyName": "Dethof",
      "affiliation": {
        "@type": "Organization",
        "name": "Institute of Geophysics, Centre for Earth System Research and Sustainability (CEN) Universit??t Hamburg  Hamburg Germany"
      },
      "@type": "Person"
    },
    {
      "name": "C. Hadziioannou",
      "givenName": "C.",
      "familyName": "Hadziioannou",
      "affiliation": {
        "@type": "Organization",
        "name": "Institute of Geophysics, Centre for Earth System Research and Sustainability (CEN) Universit??t Hamburg  Hamburg Germany"
      },
      "@type": "Person",
      "@id": "https://orcid.org/0000-0002-5312-2226"
    },
    {
      "name": "T. Meier",
      "givenName": "T.",
      "familyName": "Meier",
      "affiliation": {
        "@type": "Organization",
        "name": "Department of Geosciences Christian???Albrechts???Universit??t zu Kiel  Kiel Germany"
      },
      "@type": "Person"
    }
  ],
  "license": [
    "https://creativecommons.org/licenses/by/4.0/legalcode",
    "http://doi.wiley.com/10.1002/tdm_license_1.1"
  ],
  "datePublished": "2020-09-30",
  "dateModified": "2021-02-06T05:16:46Z",
  "isPartOf": {
    "@type": "Periodical",
    "issn": "2169-9356"
  },
  "citation": [
    {
      "@id": "https://doi.org/10.1016/s0040-1951(99)00237-1",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1016/s0040-1951(97)00290-4",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/2018gl078855",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1002/2014gl062782",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1016/0272-7714(85)90096-4",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1002/2014gl062347",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/2001jb000265",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1038/s41598-019-49586-z",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1016/j.ocemod.2012.07.005",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/2010gl046290",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1785/0119990121",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1016/j.geomorph.2012.01.006",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/2005gc000988",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1016/0077-7579(86)90036-0",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1007/bf02763955",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1023/a:1009788904007",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1016/0272-7714(88)90082-0",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1002/2015jb012210",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/2008gl036111",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1038/35042558",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1093/gji/ggt090",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/rg001i002p00177",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1785/0220110096",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/2011gc003875",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1002/2016jb013017",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1093/gji/ggx388",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1098/rspa.2007.0277",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1111/j.1365-246x.2008.03720.x",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1098/rsta.1950.0012",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1785/012003001",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/2008gl034753",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/95jc01545",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/jz069i024p05181",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/96gl00419",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1111/j.1365-246x.2006.02905.x",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/2005gl025514",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1121/1.2968296",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/97rg02287",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1002/2013eo450001",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1002/2013jc008883",
      "@type": "CreativeWork"
    },
    {
      "@id": "https://doi.org/10.1029/2010gl044288",
      "@type": "CreativeWork"
    }
  ],
  "periodical": {
    "@type": "Journal",
    "identifier": "2169-9356",
    "identifierType": "ISSN",
    "name": "Journal of Geophysical Research: Solid Earth",
    "volume": "125",
    "issue": "10"
  },
  "publisher": {
    "@type": "Organization",
    "name": "American Geophysical Union (AGU)"
  },
  "provider": {
    "@type": "Organization",
    "name": "crossref"
  }
}

# %% [markdown]
# Conversion to a DataCite structure

# %%
bolognese https://doi.org/10.1029/2020jb019770 -t datacite

# %%
<?xml version="1.0" encoding="UTF-8"?>
<resource xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://datacite.org/schema/kernel-4" xsi:schemaLocation="http://datacite.org/schema/kernel-4 http://schema.datacite.org/meta/kernel-4/metadata.xsd">
  <identifier identifierType="DOI">10.1029/2020jb019770</identifier>
  <creators>
    <creator>
      <creatorName nameType="Personal">Becker, D.</creatorName>
      <givenName>D.</givenName>
      <familyName>Becker</familyName>
      <nameIdentifier nameIdentifierScheme="ORCID" schemeURI="https://orcid.org">https://orcid.org/0000-0002-9414-2135</nameIdentifier>
      <affiliation>Institute of Geophysics, Centre for Earth System Research and Sustainability (CEN) Universit??t Hamburg  Hamburg Germany</affiliation>
    </creator>
    <creator>
      <creatorName nameType="Personal">Cristiano, L.</creatorName>
      <givenName>L.</givenName>
      <familyName>Cristiano</familyName>
      <affiliation>Department of Geosciences Christian???Albrechts???Universit??t zu Kiel  Kiel Germany</affiliation>
      <affiliation>Now at GFZ German Research Centre for Geosciences  Potsdam Germany</affiliation>
    </creator>
    <creator>
      <creatorName nameType="Personal">Peikert, J.</creatorName>
      <givenName>J.</givenName>
      <familyName>Peikert</familyName>
      <affiliation>Department of Geosciences Christian???Albrechts???Universit??t zu Kiel  Kiel Germany</affiliation>
    </creator>
    <creator>
      <creatorName nameType="Personal">Kruse, T.</creatorName>
      <givenName>T.</givenName>
      <familyName>Kruse</familyName>
      <affiliation>Department of Geosciences Christian???Albrechts???Universit??t zu Kiel  Kiel Germany</affiliation>
    </creator>
    <creator>
      <creatorName nameType="Personal">Dethof, F.</creatorName>
      <givenName>F.</givenName>
      <familyName>Dethof</familyName>
      <affiliation>Institute of Geophysics, Centre for Earth System Research and Sustainability (CEN) Universit??t Hamburg  Hamburg Germany</affiliation>
    </creator>
    <creator>
      <creatorName nameType="Personal">Hadziioannou, C.</creatorName>
      <givenName>C.</givenName>
      <familyName>Hadziioannou</familyName>
      <nameIdentifier nameIdentifierScheme="ORCID" schemeURI="https://orcid.org">https://orcid.org/0000-0002-5312-2226</nameIdentifier>
      <affiliation>Institute of Geophysics, Centre for Earth System Research and Sustainability (CEN) Universit??t Hamburg  Hamburg Germany</affiliation>
    </creator>
    <creator>
      <creatorName nameType="Personal">Meier, T.</creatorName>
      <givenName>T.</givenName>
      <familyName>Meier</familyName>
      <affiliation>Department of Geosciences Christian???Albrechts???Universit??t zu Kiel  Kiel Germany</affiliation>
    </creator>
  </creators>
  <titles>
    <title>Temporal Modulation of the Local Microseism in the North Sea</title>
  </titles>
  <publisher>American Geophysical Union (AGU)</publisher>
  <publicationYear>2020</publicationYear>
  <resourceType resourceTypeGeneral="JournalArticle">JournalArticle</resourceType>
  <dates>
    <date dateType="Issued">2020-09-30</date>
    <date dateType="Updated">2021-02-06T05:16:46Z</date>
  </dates>
  <relatedIdentifiers>
    <relatedIdentifier relatedIdentifierType="ISSN" relationType="IsPartOf" resourceTypeGeneral="Collection">2169-9356</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1016/s0040-1951(99)00237-1</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1016/s0040-1951(97)00290-4</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/2018gl078855</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1002/2014gl062782</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1016/0272-7714(85)90096-4</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1002/2014gl062347</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/2001jb000265</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1038/s41598-019-49586-z</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1016/j.ocemod.2012.07.005</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/2010gl046290</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1785/0119990121</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1016/j.geomorph.2012.01.006</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/2005gc000988</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1016/0077-7579(86)90036-0</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1007/bf02763955</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1023/a:1009788904007</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1016/0272-7714(88)90082-0</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1002/2015jb012210</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/2008gl036111</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1038/35042558</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1093/gji/ggt090</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/rg001i002p00177</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1785/0220110096</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/2011gc003875</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1002/2016jb013017</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1093/gji/ggx388</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1098/rspa.2007.0277</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1111/j.1365-246x.2008.03720.x</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1098/rsta.1950.0012</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1785/012003001</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/2008gl034753</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/95jc01545</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/jz069i024p05181</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/96gl00419</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1111/j.1365-246x.2006.02905.x</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/2005gl025514</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1121/1.2968296</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/97rg02287</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1002/2013eo450001</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1002/2013jc008883</relatedIdentifier>
    <relatedIdentifier relatedIdentifierType="DOI" relationType="References">10.1029/2010gl044288</relatedIdentifier>
  </relatedIdentifiers>
  <sizes/>
  <formats/>
  <version/>
  <rightsList>
    <rights rightsURI="https://creativecommons.org/licenses/by/4.0/legalcode" rightsIdentifier="cc-by-4.0" rightsIdentifierScheme="SPDX" schemeURI="https://spdx.org/licenses/">Creative Commons Attribution 4.0 International</rights>
    <rights rightsURI="http://doi.wiley.com/10.1002/tdm_license_1.1"/>
  </rightsList>
  <descriptions>
    <description descriptionType="SeriesInformation">Journal of Geophysical Research: Solid Earth, 125(10)</description>
  </descriptions>
</resource>

# %% [markdown]
# Convert to a BibTeX file

# %% [markdown]
# bolognese https://doi.org/10.7554/elife.01567 -t bibtex

# %%
@article{https://doi.org/10.1029/2020jb019770,
  doi = {10.1029/2020jb019770},
  url = {https://onlinelibrary.wiley.com/doi/10.1029/2020JB019770},
  author = {Becker, D. and Cristiano, L. and Peikert, J. and Kruse, T. and Dethof, F. and Hadziioannou, C. and Meier, T.},
  title = {Temporal Modulation of the Local Microseism in the North Sea},
  journal = {Journal of Geophysical Research: Solid Earth},
  volume = {125},
  issue = {10},
  publisher = {American Geophysical Union (AGU)},
  year = {2020},
  copyright = {Creative Commons Attribution 4.0 International}
}

# %%
bolognese https://doi.org/10.1029/2020jb019770 -t csv
10.1029/2020jb019770,https://onlinelibrary.wiley.com/doi/10.1029/2020JB019770,2021-02-02,findable,JournalArticle,JournalArticle,Temporal Modulation of the Local Microseism in the North Sea,"Becker, D. and Cristiano, L. and Peikert, J. and Kruse, T. and Dethof, F. and Hadziioannou, C. and Meier, T.",American Geophysical Union (AGU),2020

# %% [markdown]
# Doesn't work like a charm for all the DOIs ..

# %% [markdown]
# additional sources: https://typeset.io/for-publishers/convert/word-to-datacite-xml/

# %%
How to extract a dictionary from a DOI: RESTAPI toolbox
