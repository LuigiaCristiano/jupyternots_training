# %% [markdown]
# # Upload nexus file from published dataset

# %% [markdown]
# We upload a file we downloaded from the HZB data publication service
# The data access is enabled to all the users after the embargo of 5 years
# Here for semplicity we upload the .nxs from publication as local file

# %% [markdown]
# We use a package in Python to upload Nexus files : NeXpy, nexusformat https://nexpy.github.io

# %%
from nexusformat.nexus import *
datapath='/home/luigia/Documents/metadata_course/data_public1_HZB/'
filename='./D2O_E2_data.nxs'
a=nxload(datapath+filename)

# %% [markdown]
# # 1. Understand more on the file structure

# %%
print(a)
# Out:
# root

# %%
print(a.tree)
# Out:
# root:NXroot
#   @HDF5_Version = '1.8.8'
#   @NeXus_version = '4.2.0'
#   @file_copy = 'D:\Projects\D2O\fc3.nxs'
#   @file_name = 'D:\Projects\D2O\2012-12\fc mode data\fc3_del_p...'
#   @file_time = '2012-12-14T10:34:27+01:00'
#   entry_1:NXentry
#     E2:NXinstrument
#       ADET1:NXdetector
#         active_window = int16(4)
#         board_parameter:CARdirectory
#           DSP_buffer = float64(1442)
#             @description = 'Size of DSP buffer'
#             @units = 'kWords'
#           RAW_mode = float64(1442)
#             @description = 'RAW Mode on(1)/off(0)'
#           TDC_trigger_latency = float64(1442)
#             @description = '106 approx. 4.5 ns'
#           TDL_X_DSP = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_X_FPGA = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_Y_DSP = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_Y_FPGA = float64(1442)
#             @description = 'TDC'
#             @units = 'channel'
#           board_parameter_array = float64(1442x30)
#           delta_TDL_X_DSP = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_X_FPGA = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_Y_DSP = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_Y_FPGA = float64(1442)
#             @description = 'TDC'
#             @units = 'channel'
#           f_resolution = float64(1442)
#             @description = 'frequency resolution TDC'
#             @units = 'ps'
#           hist_1D = float64(1442)
#             @description = 'size of dead time histogram'
#           hist_2D0 = float64(1442)
#           hist_2D1 = float64(1442)
#           latency = float64(1442)
#             @description = 'Latency'
#             @units = 'ns'
#           resolution = float64(1442)
#             @description = 'TDC resolution'
#             @units = 'ps'
#           standard_1D_DSP_size = float64(1442)
#             @description = 'size of dead time sprectra'
#             @units = 'byte'
#           test_generator_frequency_coefficient = float64(1442)
#           trigger_window = float64(1442)
#             @description = 'TDC trigger window'
#             @units = 'ns'
#           unused:CARdirectory
#             ADC_threshold_level = float64(1442)
#             TOF_mode = float64(1442)
#             TOF_number_of_time_channels = float64(1442)
#             TOF_time_channel_width = float64(1442)
#             TOF_window_delay_register = float64(1442)
#             bits_shifted_in_pos = float64(1442)
#             enable_test_generation = float64(1442)
#             look_up_table_file = float64(1442)
#           x_lenghth = float64(1442)
#             @description = 'histogram channels'
#             @units = 'pixel'
#           y_lenghth = float64(1442)
#             @description = 'histogram channel'
#             @units = 'pixel'
#         data = int32(1442x256x256)
#           @axes = '[x,y]'
#           @units = 'number'
#         dead_time_information:CARdirectory
#           DSP_Input = float64(1442)
#           DSP_NoHeader = float64(1442)
#           DSP_bad_X_sum = float64(1442)
#           DSP_bad_Y_sum = float64(1442)
#           DSP_dead_time = float64(1442)
#           DSP_lost_x1 = float64(1442)
#           DSP_lost_x2 = float64(1442)
#           DSP_lost_y1 = float64(1442)
#           DSP_lost_y2 = float64(1442)
#           DSP_refused = float64(1442)
#           FPGA_bad_X_sum = float64(1442)
#           FPGA_bad_Y_sum = float64(1442)
#           FPGA_discard = float64(1442)
#             @description = 'sum of all bad events'
#           FPGA_lost_starts = float64(1442)
#           FPGA_lost_tr = float64(1442)
#           FPGA_lost_x1 = float64(1442)
#           FPGA_lost_x2 = float64(1442)
#           FPGA_lost_y1 = float64(1442)
#           FPGA_lost_y2 = float64(1442)
#           PC_Input = float64(1442)
#           PC_NoHeader = float64(1442)
#           PC_bad_X_sum = float64(1442)
#           PC_bad_Y_sum = float64(1442)
#           PC_lost_x1 = float64(1442)
#           PC_lost_x2 = float64(1442)
#           PC_lost_y1 = float64(1442)
#           PC_lost_y2 = float64(1442)
#           accepted = float64(1442)
#           dead_time_array = float64(1442x30)
#           starts = float64(1442)
#             @description = 'all start events; ratio of start to FPGA_disca...'
#           stored = float64(1442)
#         description = 'Denex 00?'
#         detector_house:NXpositioner
#           description = 'Position of the detector housing. Additional to the indi...'
#           master_value = float32(1442)
#           name = 'TTHS'
#           offset = 0.0
#             @units = 'degrees'
#           position_prestart = 10.0
#             @units = 'degrees'
#           soft_limit_max = 25.0
#           soft_limit_min = -5.0
#           timeout = 300
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         detector_number = 1
#         discard_event_ratio = float64(1442)
#         distance = float32(1442)
#         efficiency:NXdata
#           comment = '...'
#           efficiency = float64(256x256)
#             @file = '/datacollector/data/E2/xml/E2_Eff.xml'
#             @format = 'xml'
#             @source_name = 'EffXML'
#         factor = float64(1442x256x256)
#         gas_pressure = 6.0
#           @mixture = '3He: 4.8 bar and CF4: 1.2 bar'
#           @units = 'bars'
#         histogramming:CARdirectory
#           H_X1-X2_User_1D1_dsp_after_run = int32(1442x256)
#           H_X1-X2_Y1-Y2_User_2D11_dsp_run = int32(1442x256x256)
#           H_Y1-Y2_User_1D2_dsp_after_run = int32(1442x256)
#           X1-X2_Y1-Y2_dsp = int32(1442x256x256)
#           X1pX2_dsp = int32(1442x10000)
#           Y1pY2_dsp = int32(1442x10000)
#         integral = int32(1442)
#         local_name = 'ADET1'
#         logs:CARdirectory
#           root_log = '                          ------------------------------...'
#             @file = '/datacollector/data/E2/rootlogs/e209418_Det1.r...'
#             @format = 'text'
#             @source_name = 'Log_det1'
#           scan_log = '2012-12-10 12:00:33     4    40.44        3459       271...'
#             @file = '/datacollector/data/E2/rootlogs/Caress_Scans_e...'
#             @format = 'text'
#             @source_name = 'Carscan_det1'
#         polar_angle = float64(1442)
#         position:NXpositioner
#           description = 'Position of the 1st detector in the housing. Additional ...'
#           master_value = float32(1442)
#           name = 'TTH1'
#           offset = -0.03999999910593033
#             @units = 'degrees'
#           position_prestart = 2.9994330406188965
#             @units = 'degrees'
#           soft_limit_max = 25.399999618530273
#           soft_limit_min = 2.9000000953674316
#           timeout = 300
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         translation:NXpositioner
#           description = 'Translation of the detectorhouse.'
#           master_value = float32(1442)
#           name = 'HTRANS'
#           offset = 0.0
#             @units = 'mm'
#           position_prestart = -0.692307710647583
#             @units = 'mm'
#           soft_limit_max = 150.0
#           soft_limit_min = -150.0
#           timeout = 10
#           tolerance = 0.0010000000474974513
#           value = float32(1442)
#         type = 'He3'
#         x_offset = [2.560e+02 1.280e+02 1.277e-01]
#           @axis = '3'
#           @primary = '1'
#           @units = 'pixel'
#         x_pixel_number = 256.0
#         x_pixel_offset = 128.0
#         x_pixel_size = 0.12770000100135803
#         y_offset = [2.560e+02 7.500e+01 1.277e-01]
#           @axis = '4'
#           @primary = '1'
#           @units = 'pixel'
#         y_pixel_number = 256.0
#         y_pixel_offset = 75.0
#         y_pixel_size = 0.12770000100135803
#       ADET2:NXdetector
#         active_window = int16(4)
#         board_parameter:CARdirectory
#           DSP_buffer = float64(1442)
#             @description = 'Size of DSP buffer'
#             @units = 'kWords'
#           RAW_mode = float64(1442)
#             @description = 'RAW Mode on(1)/off(0)'
#           TDC_trigger_latency = float64(1442)
#             @description = '106 approx. 4.5 ns'
#           TDL_X_DSP = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_X_FPGA = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_Y_DSP = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_Y_FPGA = float64(1442)
#             @description = 'TDC'
#             @units = 'channel'
#           board_parameter_array = float64(1442x30)
#           delta_TDL_X_DSP = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_X_FPGA = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_Y_DSP = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_Y_FPGA = float64(1442)
#             @description = 'TDC'
#             @units = 'channel'
#           f_resolution = float64(1442)
#             @description = 'frequency resolution TDC'
#             @units = 'ps'
#           hist_1D = float64(1442)
#             @description = 'size of dead time histogram'
#           hist_2D0 = float64(1442)
#           hist_2D1 = float64(1442)
#           latency = float64(1442)
#             @description = 'Latency'
#             @units = 'ns'
#           resolution = float64(1442)
#             @description = 'TDC resolution'
#             @units = 'ps'
#           standard_1D_DSP_size = float64(1442)
#             @description = 'size of dead time sprectra'
#             @units = 'byte'
#           test_generator_frequency_coefficient = float64(1442)
#           trigger_window = float64(1442)
#             @description = 'TDC trigger window'
#             @units = 'ns'
#           unused:CARdirectory
#             ADC_threshold_level = float64(1442)
#             TOF_mode = float64(1442)
#             TOF_number_of_time_channels = float64(1442)
#             TOF_time_channel_width = float64(1442)
#             TOF_window_delay_register = float64(1442)
#             bits_shifted_in_pos = float64(1442)
#             enable_test_generation = float64(1442)
#             look_up_table_file = float64(1442)
#           x_lenghth = float64(1442)
#             @description = 'histogram channels'
#             @units = 'pixel'
#           y_lenghth = float64(1442)
#             @description = 'histogram channel'
#             @units = 'pixel'
#         data = int32(1442x256x256)
#           @axes = '[x,y]'
#           @units = 'number'
#         dead_time_information:CARdirectory
#           DSP_Input = float64(1442)
#           DSP_NoHeader = float64(1442)
#           DSP_bad_X_sum = float64(1442)
#           DSP_bad_Y_sum = float64(1442)
#           DSP_dead_time = float64(1442)
#           DSP_lost_x1 = float64(1442)
#           DSP_lost_x2 = float64(1442)
#           DSP_lost_y1 = float64(1442)
#           DSP_lost_y2 = float64(1442)
#           DSP_refused = float64(1442)
#           FPGA_bad_X_sum = float64(1442)
#           FPGA_bad_Y_sum = float64(1442)
#           FPGA_discard = float64(1442)
#             @description = 'sum of all bad events'
#           FPGA_lost_starts = float64(1442)
#           FPGA_lost_tr = float64(1442)
#           FPGA_lost_x1 = float64(1442)
#           FPGA_lost_x2 = float64(1442)
#           FPGA_lost_y1 = float64(1442)
#           FPGA_lost_y2 = float64(1442)
#           PC_Input = float64(1442)
#           PC_NoHeader = float64(1442)
#           PC_bad_X_sum = float64(1442)
#           PC_bad_Y_sum = float64(1442)
#           PC_lost_x1 = float64(1442)
#           PC_lost_x2 = float64(1442)
#           PC_lost_y1 = float64(1442)
#           PC_lost_y2 = float64(1442)
#           accepted = float64(1442)
#           dead_time_array = float64(1442x30)
#           starts = float64(1442)
#             @description = 'all start events; ratio of start to FPGA_disca...'
#           stored = float64(1442)
#         description = 'Denex 00?'
#         detector_house:NXpositioner
#           description = 'Position of the detector housing. Additional to the indi...'
#           master_value = float32(1442)
#           name = 'TTHS'
#           offset = 0.0
#             @units = 'degrees'
#           position_prestart = 10.0
#             @units = 'degrees'
#           soft_limit_max = 25.0
#           soft_limit_min = -5.0
#           timeout = 300
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         detector_number = 2
#         discard_event_ratio = float64(1442)
#         distance = float32(1442)
#         efficiency:NXdata
#           comment = '...'
#           efficiency = float64(256x256)
#             @file = '/datacollector/data/E2/xml/E2_Eff.xml'
#             @format = 'xml'
#             @source_name = 'EffXML'
#         factor = float64(1442x256x256)
#         gas_pressure = 6.0
#           @mixture = '3He: 4.8 bar and CF4: 1.2 bar'
#           @units = 'bars'
#         histogramming:CARdirectory
#           H_X1-X2_User_1D1_dsp_after_run = int32(1442x256)
#           H_X1-X2_Y1-Y2_User_2D11_dsp_run = int32(1442x256x256)
#           H_Y1-Y2_User_1D2_dsp_after_run = int32(1442x256)
#           X1-X2_Y1-Y2_dsp = int32(1442x256x256)
#           X1pX2_dsp = int32(1442x10000)
#           Y1pY2_dsp = int32(1442x10000)
#         integral = int32(1442)
#         local_name = 'ADET2'
#         logs:CARdirectory
#           root_log = '                          ------------------------------...'
#             @file = '/datacollector/data/E2/rootlogs/e209418_Det2.r...'
#             @format = 'text'
#             @source_name = 'Log_det2'
#           scan_log = '2012-12-10 12:00:32     4    40.91        3291       290...'
#             @file = '/datacollector/data/E2/rootlogs/Caress_Scans_e...'
#             @format = 'text'
#             @source_name = 'Carscan_det2'
#         polar_angle = float64(1442)
#         position:NXpositioner
#           description = 'Position of the 2nd detector in the housing. Additional ...'
#           master_value = float32(1442)
#           name = 'TTH2'
#           offset = -0.009999999776482582
#             @units = 'degrees'
#           position_prestart = 22.998010635375977
#             @units = 'degrees'
#           soft_limit_max = 41.5
#           soft_limit_min = 18.899999618530273
#           timeout = 300
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         translation:NXpositioner
#           description = 'Translation of the detectorhouse.'
#           master_value = float32(1442)
#           name = 'HTRANS'
#           offset = 0.0
#             @units = 'mm'
#           position_prestart = -0.692307710647583
#             @units = 'mm'
#           soft_limit_max = 150.0
#           soft_limit_min = -150.0
#           timeout = 10
#           tolerance = 0.0010000000474974513
#           value = float32(1442)
#         type = 'He3'
#         x_offset = [2.560e+02 1.280e+02 1.277e-01]
#           @axis = '3'
#           @primary = '1'
#           @units = 'pixel'
#         x_pixel_number = 256.0
#         x_pixel_offset = 128.0
#         x_pixel_size = 0.12200000137090683
#         y_offset = [2.560e+02 7.500e+01 1.277e-01]
#           @axis = '4'
#           @primary = '1'
#           @units = 'pixel'
#         y_pixel_number = 256.0
#         y_pixel_offset = 75.0
#         y_pixel_size = 0.12200000137090683
#       ADET3:NXdetector
#         active_window = int16(4)
#         board_parameter:CARdirectory
#           DSP_buffer = float64(1442)
#             @description = 'Size of DSP buffer'
#             @units = 'kWords'
#           RAW_mode = float64(1442)
#             @description = 'RAW Mode on(1)/off(0)'
#           TDC_trigger_latency = float64(1442)
#             @description = '106 approx. 4.5 ns'
#           TDL_X_DSP = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_X_FPGA = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_Y_DSP = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_Y_FPGA = float64(1442)
#             @description = 'TDC'
#             @units = 'channel'
#           board_parameter_array = float64(1442x30)
#           delta_TDL_X_DSP = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_X_FPGA = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_Y_DSP = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_Y_FPGA = float64(1442)
#             @description = 'TDC'
#             @units = 'channel'
#           f_resolution = float64(1442)
#             @description = 'frequency resolution TDC'
#             @units = 'ps'
#           hist_1D = float64(1442)
#             @description = 'size of dead time histogram'
#           hist_2D0 = float64(1442)
#           hist_2D1 = float64(1442)
#           latency = float64(1442)
#             @description = 'Latency'
#             @units = 'ns'
#           resolution = float64(1442)
#             @description = 'TDC resolution'
#             @units = 'ps'
#           standard_1D_DSP_size = float64(1442)
#             @description = 'size of dead time sprectra'
#             @units = 'byte'
#           test_generator_frequency_coefficient = float64(1442)
#           trigger_window = float64(1442)
#             @description = 'TDC trigger window'
#             @units = 'ns'
#           unused:CARdirectory
#             ADC_threshold_level = float64(1442)
#             TOF_mode = float64(1442)
#             TOF_number_of_time_channels = float64(1442)
#             TOF_time_channel_width = float64(1442)
#             TOF_window_delay_register = float64(1442)
#             bits_shifted_in_pos = float64(1442)
#             enable_test_generation = float64(1442)
#             look_up_table_file = float64(1442)
#           x_lenghth = float64(1442)
#             @description = 'histogram channels'
#             @units = 'pixel'
#           y_lenghth = float64(1442)
#             @description = 'histogram channel'
#             @units = 'pixel'
#         data = int32(1442x256x256)
#           @axes = '[x,y]'
#           @units = 'number'
#         dead_time_information:CARdirectory
#           DSP_Input = float64(1442)
#           DSP_NoHeader = float64(1442)
#           DSP_bad_X_sum = float64(1442)
#           DSP_bad_Y_sum = float64(1442)
#           DSP_dead_time = float64(1442)
#           DSP_lost_x1 = float64(1442)
#           DSP_lost_x2 = float64(1442)
#           DSP_lost_y1 = float64(1442)
#           DSP_lost_y2 = float64(1442)
#           DSP_refused = float64(1442)
#           FPGA_bad_X_sum = float64(1442)
#           FPGA_bad_Y_sum = float64(1442)
#           FPGA_discard = float64(1442)
#             @description = 'sum of all bad events'
#           FPGA_lost_starts = float64(1442)
#           FPGA_lost_tr = float64(1442)
#           FPGA_lost_x1 = float64(1442)
#           FPGA_lost_x2 = float64(1442)
#           FPGA_lost_y1 = float64(1442)
#           FPGA_lost_y2 = float64(1442)
#           PC_Input = float64(1442)
#           PC_NoHeader = float64(1442)
#           PC_bad_X_sum = float64(1442)
#           PC_bad_Y_sum = float64(1442)
#           PC_lost_x1 = float64(1442)
#           PC_lost_x2 = float64(1442)
#           PC_lost_y1 = float64(1442)
#           PC_lost_y2 = float64(1442)
#           accepted = float64(1442)
#           dead_time_array = float64(1442x30)
#           starts = float64(1442)
#             @description = 'all start events; ratio of start to FPGA_disca...'
#           stored = float64(1442)
#         description = 'Denex 00?'
#         detector_house:NXpositioner
#           description = 'Position of the detector housing. Additional to the indi...'
#           master_value = float32(1442)
#           name = 'TTHS'
#           offset = 0.0
#             @units = 'degrees'
#           position_prestart = 10.0
#             @units = 'degrees'
#           soft_limit_max = 25.0
#           soft_limit_min = -5.0
#           timeout = 300
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         detector_number = 3
#         discard_event_ratio = float64(1442)
#         distance = float32(1442)
#         efficiency:NXdata
#           comment = '...'
#           efficiency = float64(256x256)
#             @file = '/datacollector/data/E2/xml/E2_Eff.xml'
#             @format = 'xml'
#             @source_name = 'EffXML'
#         factor = float64(1442x256x256)
#         gas_pressure = 6.0
#           @mixture = '3He: 4.8 bar and CF4: 1.2 bar'
#           @units = 'bars'
#         histogramming:CARdirectory
#           H_X1-X2_User_1D1_dsp_after_run = int32(1442x256)
#           H_X1-X2_Y1-Y2_User_2D11_dsp_run = int32(1442x256x256)
#           H_Y1-Y2_User_1D2_dsp_after_run = int32(1442x256)
#           X1-X2_Y1-Y2_dsp = int32(1442x256x256)
#           X1pX2_dsp = int32(1442x10000)
#           Y1pY2_dsp = int32(1442x10000)
#         integral = int32(1442)
#         local_name = 'ADET3'
#         logs:CARdirectory
#           root_log = '                          ------------------------------...'
#             @file = '/datacollector/data/E2/rootlogs/e209418_Det3.r...'
#             @format = 'text'
#             @source_name = 'Log_det3'
#           scan_log = '-----------------   E2_Detector_3_Commissioning_run9385_...'
#             @file = '/datacollector/data/E2/rootlogs/Caress_Scans_e...'
#             @format = 'text'
#             @source_name = 'Carscan_det3'
#         polar_angle = float64(1442)
#         position:NXpositioner
#           description = 'Position of the 3rd detector in the housing. Additional ...'
#           master_value = float32(1442)
#           name = 'TTH3'
#           offset = -0.029999999329447746
#             @units = 'degrees'
#           position_prestart = 42.998958587646484
#             @units = 'degrees'
#           soft_limit_max = 57.5
#           soft_limit_min = 34.900001525878906
#           timeout = 300
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         translation:NXpositioner
#           description = 'Translation of the detectorhouse.'
#           master_value = float32(1442)
#           name = 'HTRANS'
#           offset = 0.0
#             @units = 'mm'
#           position_prestart = -0.692307710647583
#             @units = 'mm'
#           soft_limit_max = 150.0
#           soft_limit_min = -150.0
#           timeout = 10
#           tolerance = 0.0010000000474974513
#           value = float32(1442)
#         type = 'He3'
#         x_offset = [2.560e+02 1.280e+02 1.277e-01]
#           @axis = '3'
#           @primary = '1'
#           @units = 'pixel'
#         x_pixel_number = 256.0
#         x_pixel_offset = 128.0
#         x_pixel_size = 0.12770000100135803
#         y_offset = [2.560e+02 7.500e+01 1.277e-01]
#           @axis = '4'
#           @primary = '1'
#           @units = 'pixel'
#         y_pixel_number = 256.0
#         y_pixel_offset = 75.0
#         y_pixel_size = 0.12770000100135803
#       ADET4:NXdetector
#         active_window = int16(4)
#         board_parameter:CARdirectory
#           DSP_buffer = float64(1442)
#             @description = 'Size of DSP buffer'
#             @units = 'kWords'
#           RAW_mode = float64(1442)
#             @description = 'RAW Mode on(1)/off(0)'
#           TDC_trigger_latency = float64(1442)
#             @description = '106 approx. 4.5 ns'
#           TDL_X_DSP = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_X_FPGA = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_Y_DSP = float64(1442)
#             @description = 'Peak center'
#             @units = 'channel'
#           TDL_Y_FPGA = float64(1442)
#             @description = 'TDC'
#             @units = 'channel'
#           board_parameter_array = float64(1442x30)
#           delta_TDL_X_DSP = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_X_FPGA = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_Y_DSP = float64(1442)
#             @description = 'Peak width'
#             @units = 'channel'
#           delta_TDL_Y_FPGA = float64(1442)
#             @description = 'TDC'
#             @units = 'channel'
#           f_resolution = float64(1442)
#             @description = 'frequency resolution TDC'
#             @units = 'ps'
#           hist_1D = float64(1442)
#             @description = 'size of dead time histogram'
#           hist_2D0 = float64(1442)
#           hist_2D1 = float64(1442)
#           latency = float64(1442)
#             @description = 'Latency'
#             @units = 'ns'
#           resolution = float64(1442)
#             @description = 'TDC resolution'
#             @units = 'ps'
#           standard_1D_DSP_size = float64(1442)
#             @description = 'size of dead time sprectra'
#             @units = 'byte'
#           test_generator_frequency_coefficient = float64(1442)
#           trigger_window = float64(1442)
#             @description = 'TDC trigger window'
#             @units = 'ns'
#           unused:CARdirectory
#             ADC_threshold_level = float64(1442)
#             TOF_mode = float64(1442)
#             TOF_number_of_time_channels = float64(1442)
#             TOF_time_channel_width = float64(1442)
#             TOF_window_delay_register = float64(1442)
#             bits_shifted_in_pos = float64(1442)
#             enable_test_generation = float64(1442)
#             look_up_table_file = float64(1442)
#           x_lenghth = float64(1442)
#             @description = 'histogram channels'
#             @units = 'pixel'
#           y_lenghth = float64(1442)
#             @description = 'histogram channel'
#             @units = 'pixel'
#         data = int32(1442x256x256)
#           @axes = '[x,y]'
#           @units = 'number'
#         dead_time_information:CARdirectory
#           DSP_Input = float64(1442)
#           DSP_NoHeader = float64(1442)
#           DSP_bad_X_sum = float64(1442)
#           DSP_bad_Y_sum = float64(1442)
#           DSP_dead_time = float64(1442)
#           DSP_lost_x1 = float64(1442)
#           DSP_lost_x2 = float64(1442)
#           DSP_lost_y1 = float64(1442)
#           DSP_lost_y2 = float64(1442)
#           DSP_refused = float64(1442)
#           FPGA_bad_X_sum = float64(1442)
#           FPGA_bad_Y_sum = float64(1442)
#           FPGA_discard = float64(1442)
#             @description = 'sum of all bad events'
#           FPGA_lost_starts = float64(1442)
#           FPGA_lost_tr = float64(1442)
#           FPGA_lost_x1 = float64(1442)
#           FPGA_lost_x2 = float64(1442)
#           FPGA_lost_y1 = float64(1442)
#           FPGA_lost_y2 = float64(1442)
#           PC_Input = float64(1442)
#           PC_NoHeader = float64(1442)
#           PC_bad_X_sum = float64(1442)
#           PC_bad_Y_sum = float64(1442)
#           PC_lost_x1 = float64(1442)
#           PC_lost_x2 = float64(1442)
#           PC_lost_y1 = float64(1442)
#           PC_lost_y2 = float64(1442)
#           accepted = float64(1442)
#           dead_time_array = float64(1442x30)
#           starts = float64(1442)
#             @description = 'all start events; ratio of start to FPGA_disca...'
#           stored = float64(1442)
#         description = 'Denex 00?'
#         detector_house:NXpositioner
#           description = 'Position of the detector housing. Additional to the indi...'
#           master_value = float32(1442)
#           name = 'TTHS'
#           offset = 0.0
#             @units = 'degrees'
#           position_prestart = 10.0
#             @units = 'degrees'
#           soft_limit_max = 25.0
#           soft_limit_min = -5.0
#           timeout = 300
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         detector_number = 4
#         discard_event_ratio = float64(1442)
#         distance = float32(1442)
#         efficiency:NXdata
#           comment = '...'
#           efficiency = float64(256x256)
#             @file = '/datacollector/data/E2/xml/E2_Eff.xml'
#             @format = 'xml'
#             @source_name = 'EffXML'
#         factor = float64(1442x256x256)
#         gas_pressure = 6.0
#           @mixture = '3He: 4.8 bar and CF4: 1.2 bar'
#           @units = 'bars'
#         histogramming:CARdirectory
#           H_X1-X2_User_1D1_dsp_after_run = int32(1442x256)
#           H_X1-X2_Y1-Y2_User_2D11_dsp_run = int32(1442x256x256)
#           H_Y1-Y2_User_1D2_dsp_after_run = int32(1442x256)
#           X1-X2_Y1-Y2_dsp = int32(1442x256x256)
#           X1pX2_dsp = int32(1442x10000)
#           Y1pY2_dsp = int32(1442x10000)
#         integral = int32(1442)
#         local_name = 'ADET4'
#         logs:CARdirectory
#           root_log = '                          ------------------------------...'
#             @file = '/datacollector/data/E2/rootlogs/e209418_Det4.r...'
#             @format = 'text'
#             @source_name = 'Log_det4'
#           scan_log = '-----------------   E2_Detector_4_Commissioning_run9385_...'
#             @file = '/datacollector/data/E2/rootlogs/Caress_Scans_e...'
#             @format = 'text'
#             @source_name = 'Carscan_det4'
#         polar_angle = float64(1442)
#         position:NXpositioner
#           description = 'Position of the 4th detector in the housing. Additional ...'
#           master_value = float32(1442)
#           name = 'TTH4'
#           offset = -0.019999999552965164
#             @units = 'degrees'
#           position_prestart = 62.99848556518555
#             @units = 'degrees'
#           soft_limit_max = 73.5
#           soft_limit_min = 50.900001525878906
#           timeout = 300
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         translation:NXpositioner
#           description = 'Translation of the detectorhouse.'
#           master_value = float32(1442)
#           name = 'HTRANS'
#           offset = 0.0
#             @units = 'mm'
#           position_prestart = -0.692307710647583
#             @units = 'mm'
#           soft_limit_max = 150.0
#           soft_limit_min = -150.0
#           timeout = 10
#           tolerance = 0.0010000000474974513
#           value = float32(1442)
#         type = 'He3'
#         x_offset = [2.560e+02 1.280e+02 1.277e-01]
#           @axis = '3'
#           @primary = '1'
#           @units = 'pixel'
#         x_pixel_number = 256.0
#         x_pixel_offset = 128.0
#         x_pixel_size = 0.12770000100135803
#         y_offset = [2.560e+02 7.500e+01 1.277e-01]
#           @axis = '4'
#           @primary = '1'
#           @units = 'pixel'
#         y_pixel_number = 256.0
#         y_pixel_offset = 75.0
#         y_pixel_size = 0.12770000100135803
#       BER_II:NXsource
#         distance = 3.0
#           @units = 'm'
#           @unitsdef = 'm = meter'
#         name = 'BER II @ HMI Berlin, Germany'
#         power = 0.0
#           @units = 'MW'
#           @unitsdef = 'MW = 1e6 watt'
#         probe = 'neutron'
#         type = 'Reactor Neutron Source'
#       beamstop:NXbeam_stop
#         distance_to_detector = 300.0
#           @units = 'm'
#           @unitsdef = 'm = meter'
#       collimator_radial:NXcollimator
#         absorbing_material = 'Gadulinium Oxide on Aluminium plates'
#         adjustment = float32(1442)
#           @lower_limit = -110.0
#           @offset = 0.0
#           @timeout = 60
#           @tolerance = 0.10000000149011612
#           @units = 'steps'
#           @upper_limit = 110.0
#         alignment:NXpositioner
#           master_value = float32(1442)
#           name = 'OMGR'
#           offset = 0.0
#             @units = 'degrees'
#           position_prestart = 75.0
#             @units = 'degrees'
#           soft_limit_max = 110.0
#           soft_limit_min = -110.0
#           timeout = 60
#           tolerance = 0.10000000149011612
#           value = float32(1442)
#         blade_spacing = 0.20000000298023224
#           @units = 'arcmin'
#           @unitsdef = 'arcmin = arcminute'
#         blade_thickness = 0.5
#           @units = '10^-3 meter'
#         frequency = float64(1442)
#           @units = 'Hz'
#           @unitsdef = 'Hz = hertz = 1/second'
#         motor:NXpositioner
#           factor = 0.0010000000474974513
#           master_value = float32(1442)
#           name = 'RADCOLL'
#           offset = 0.0
#           position_prestart = 0.0
#           soft_limit_max = 10000000000.0
#           soft_limit_min = -10000000000.0
#           timeout = 10
#           tolerance = 0.0010000000474974513
#           value = float32(1442)
#         transmitting_material = 'Air'
#         type = 'radial'
#       flat_cone_angle:NXpositioner
#         master_value = float32(1442)
#         mu_x = float32(1442)
#         mu_y = float32(1442)
#         name = 'MUTILT'
#         offset = 0.0
#           @units = 'steps'
#         position_prestart = 3.350128736201441e-06
#           @units = 'degrees'
#         soft_limit_max = 360.0
#         soft_limit_min = -360.0
#         timeout = 300
#         tolerance = 0.10000000149011612
#         value = float32(1442)
#           @units = 'degrees'
#       instrument_responsible:NXuser
#         address = 'Hahn-Meitner Platz 1, D-14109 Berlin'
#         affiliation = 'Helmholtz Zentrum Berlin erstwhile HMI Berlin, Institute...'
#         email = 'hoffmann-j@helmholtz-berlin.de'
#         fax_number = '+49 30 8062 42999'
#         name = 'Dr. J.-U. Hoffmann'
#         role = 'Instrument Scientest'
#         telephone_number = '+49 30 8062 42185'
#       monochromator:NXcrystal
#         @target = '/entry_1/E2/monochromator'
#         monochromator_changer:NXpositioner
#           Cu_Monochromator:NXcrystal
#             type = 'Cu'
#           Ge_Monochromator:NXcrystal
#             type = 'Ge'
#             wavelength = 1.2100000381469727
#               @units = 'Angstroms'
#               @unitsdef = 'Angstroms = angstrom = decinanometer'
#           PG_Monochromator:NXcrystal
#             focusing:CARdirectory
#               motor_1:NXpositioner
#                 master_value = float32(1442)
#                 name = 'M1_FOC1'
#                 offset = 0.0
#                   @units = 'steps'
#                 position_prestart = 99.99999237060547
#                   @units = 'steps'
#                 soft_limit_max = 110.0
#                   @units = 'steps'
#                 soft_limit_min = -110.0
#                   @units = 'steps'
#                 timeout = 10
#                   @units = 's'
#                   @unitsdef = 's = second'
#                 tolerance = 0.10000000149011612
#                   @units = 'steps'
#                 value = float32(1442)
#                   @units = 'steps'
#               motor_2:NXpositioner
#                 master_value = float32(1442)
#                 name = 'M1_FOC2'
#                 offset = 0.0
#                   @units = 'steps'
#                 position_prestart = 99.99999237060547
#                   @units = 'steps'
#                 soft_limit_max = 110.0
#                   @units = 'steps'
#                 soft_limit_min = -110.0
#                   @units = 'steps'
#                 timeout = 10
#                   @units = 's'
#                   @unitsdef = 's = second'
#                 tolerance = 0.10000000149011612
#                   @units = 'steps'
#                 value = float32(1442)
#                   @units = 'steps'
#             type = 'PG'
#             wavelength = 2.390000104904175
#               @units = 'Angstroms'
#               @unitsdef = 'Angstroms = angstrom = decinanometer'
#           master_value = float32(1442)
#           name = 'MONOC'
#           offset = 0.0
#             @units = 'steps'
#           position_prestart = 124.99951171875
#             @units = 'steps'
#           soft_limit_max = 250.0
#           soft_limit_min = -200.0
#           timeout = 10
#             @units = 's'
#             @unitsdef = 's = second'
#           tolerance = 0.009999999776482582
#             @units = 'steps'
#           value = float32(1442)
#             @units = 'steps'
#         omega:NXpositioner
#           master_value = float32(1442)
#           name = 'OMGM'
#           offset = 0.0
#             @units = 'degrees'
#           position_prestart = 0.500244140625
#             @units = 'degrees'
#           soft_limit_max = 30.0
#           soft_limit_min = 0.0
#           timeout = 10
#           tolerance = 0.10000000149011612
#           value = float32(1442)
#         tilting:NXpositioner
#           master_value = float32(1442)
#           name = 'MONTI'
#           offset = 0.0
#             @units = 'steps'
#           position_prestart = 14.498779296875
#             @units = 'steps'
#           soft_limit_max = 20.0
#             @units = 'steps'
#           soft_limit_min = 0.5
#             @units = 'steps'
#           timeout = 10
#             @units = 's'
#             @unitsdef = 's = second'
#           tolerance = 0.10000000149011612
#             @units = 'steps'
#           value = float32(1442)
#             @units = 'steps'
#         translation:NXpositioner
#           master_value = float32(1442)
#           name = 'MONTR'
#           offset = 0.0
#             @units = 'steps'
#           position_prestart = 6.000244140625
#             @units = 'steps'
#           soft_limit_max = 15.0
#             @units = 'steps'
#           soft_limit_min = 1.0
#             @units = 'steps'
#           timeout = 10
#             @units = 's'
#             @unitsdef = 's = second'
#           tolerance = 0.10000000149011612
#             @units = 'steps'
#           value = float32(1442)
#             @units = 'steps'
#         wavelength = 1.2109999656677246
#           @units = 'Angstroms'
#       name = 'Flat-Cone-Diffractometer'
#         @short_name = 'E2'
#       premonochromator_collimator:NXcollimator
#         absorbing_material = 'GaO on a polymer foil'
#         blade_thickness = 0.20000000298023224
#           @units = 'mm'
#         collimator_changer:CARdirectory
#           COLL:NXpositioner
#             master_value = float32(1442)
#             name = 'COLL'
#             position_prestart = 30
#               @units = 'degrees'
#             timeout = 10
#             value = float32(1442)
#           collimator15_position:NXpositioner
#             master_value = float32(1442)
#             name = 'COLL15'
#             offset = 0.0
#               @units = 'steps'
#             position_prestart = 0.0
#               @units = 'procent'
#             soft_limit_max = 150.0
#             soft_limit_min = -150.0
#             timeout = 600
#               @units = 's'
#               @unitsdef = 's = second'
#             tolerance = 0.009999999776482582
#               @units = 'steps'
#             value = float32(1442)
#           collimator15_vertical:NXcollimator
#             absorbing_material = 'GaO on a polymer foil'
#             blade_spacing = 3.0
#               @units = 'mm'
#             blade_thickness = 0.20000000298023224
#               @units = 'mm'
#               @unitsdef = 'mm = 10E-3 meter'
#             soller_angle = 15.0
#               @units = 'arcmin'
#               @unitsdef = 'arcmin = arcminute'
#             tilting:NXpositioner
#               master_value = float32(1442)
#               name = 'COLL15T'
#               offset = 0.0
#                 @units = 'steps'
#               position_prestart = -26.0
#                 @units = 'steps'
#               soft_limit_max = 150.0
#               soft_limit_min = -150.0
#               timeout = 10
#                 @units = 's'
#                 @unitsdef = 's = second'
#               tolerance = 0.004999999888241291
#                 @units = 'steps'
#               value = float32(1442)
#                 @units = 'steps'
#             transmitting_material = 'air'
#             type = 'soller'
#           collimator30_position:NXpositioner
#             master_value = float32(1442)
#             name = 'COLL30'
#             offset = 0.0
#               @units = 'steps'
#             position_prestart = 100.21417236328125
#               @units = 'procent'
#             soft_limit_max = 150.0
#             soft_limit_min = -150.0
#             timeout = 600
#               @units = 's'
#               @unitsdef = 's = second'
#             tolerance = 0.009999999776482582
#               @units = 'steps'
#             value = float32(1442)
#           collimator30_vertical:NXcollimator
#             absorbing_material = 'GaO on a polymer foil'
#             blade_thickness = 0.20000000298023224
#               @units = 'mm'
#             soller_angle = 30.0
#               @units = 'arcmin'
#               @unitsdef = 'arcmin = arcminute'
#             tilting:NXpositioner
#               master_value = float32(1442)
#               name = 'COLL30T'
#               offset = 0.0
#                 @units = 'steps'
#               position_prestart = -4.999975204467773
#                 @units = 'steps'
#               soft_limit_max = 150.0
#               soft_limit_min = -150.0
#               timeout = 10
#                 @units = 's'
#                 @unitsdef = 's = second'
#               tolerance = 0.004999999888241291
#                 @units = 'steps'
#               value = float32(1442)
#                 @units = 'steps'
#             transmitting_material = 'air'
#             type = 'soller'
#           collimator_open_vertical:NXcollimator
#             absorbing_material = 'none'
#             blade_thickness = 0.0
#               @units = 'mm'
#               @unitsdef = 'mm = 1E-3 meter'
#             soller_angle = 60.0
#               @units = 'arcmin'
#               @unitsdef = 'arcmin = arcminute'
#             transmitting_material = 'air'
#             type = 'none'
#         set_soller_angle = float32(1442)
#           @units = 'minutes'
#         soller_angle = 30.0
#           @units = 'arcmin'
#           @unitsdef = 'arcmin = arcminute'
#         tilting:NXpositioner
#           master_value = float32(1442)
#           name = 'COLL30T'
#           offset = 0.0
#             @units = 'steps'
#           position_prestart = -4.999975204467773
#             @units = 'steps'
#           soft_limit_max = 150.0
#           soft_limit_min = -150.0
#           timeout = 10
#             @units = 's'
#             @unitsdef = 's = second'
#           tolerance = 0.004999999888241291
#             @units = 'steps'
#           value = float32(1442)
#             @units = 'steps'
#         transmitting_material = 'air'
#         type = 'soller'
#     caress:CARdirectory
#       BLS:CARdirectory
#         CHI1 = [-20.   20.5]
#           @nameDef = 'CHI1'
#         CHI2 = [-20.  20.]
#           @nameDef = 'CHI2'
#         COLL15 = [-150.  150.]
#           @nameDef = 'COLL15'
#         COLL15T = [-150.  150.]
#           @nameDef = 'COLL15T'
#         COLL30 = [-150.  150.]
#           @nameDef = 'COLL30'
#         COLL30T = [-150.  150.]
#           @nameDef = 'COLL30T'
#         HTRANS = [-150.  150.]
#           @nameDef = 'HTRANS'
#         M1_FOC1 = [-110.  110.]
#           @nameDef = 'M1_FOC1'
#         M1_FOC2 = [-110.  110.]
#           @nameDef = 'M1_FOC2'
#         MONOC = [-200.  250.]
#           @nameDef = 'MONOC'
#         MONTI = [ 0.5 20. ]
#           @nameDef = 'MONTI'
#         MONTR = [ 1. 15.]
#           @nameDef = 'MONTR'
#         MUTILT = [-360.  360.]
#           @nameDef = 'MUTILT'
#         OMGM = [ 0. 30.]
#           @nameDef = 'OMGM'
#         OMGR = [-110.  110.]
#           @nameDef = 'OMGR'
#         OMGS = [-360.  360.]
#           @nameDef = 'OMGS'
#         PHIS = [-360.  360.]
#           @nameDef = 'PHIS'
#         RADCOLL = [-1.e+10  1.e+10]
#           @nameDef = 'RADCOLL'
#         TEMP = [   0. 2000.]
#           @nameDef = 'TEMP'
#         TTH1 = [ 2.9 25.4]
#           @nameDef = 'TTH1'
#         TTH2 = [18.9 41.5]
#           @nameDef = 'TTH2'
#         TTH3 = [34.9 57.5]
#           @nameDef = 'TTH3'
#         TTH4 = [50.9 73.5]
#           @nameDef = 'TTH4'
#         TTHS = [-5. 25.]
#           @nameDef = 'TTHS'
#       PROT_BEG:CARdirectory
#         T_SAM = float32(1442)
#           @nameDef = 'T_SAM'
#       PROT_END:CARdirectory
#         T_SAM = float32(1442)
#           @nameDef = 'T_SAM'
#       READ:CARdirectory
#         CHI1 = 0.000247955322265625
#           @nameDef = 'CHI1'
#         CHI2 = 1.9073486328125e-06
#           @nameDef = 'CHI2'
#         COLL = 30
#           @nameDef = 'COLL'
#         COLL15 = 0.0
#           @nameDef = 'COLL15'
#         COLL15T = -26.0
#           @nameDef = 'COLL15T'
#         COLL30 = 100.21417236328125
#           @nameDef = 'COLL30'
#         COLL30T = -4.999975204467773
#           @nameDef = 'COLL30T'
#         HTRANS = -0.692307710647583
#           @nameDef = 'HTRANS'
#         M1_FOC1 = 99.99999237060547
#           @nameDef = 'M1_FOC1'
#         M1_FOC2 = 99.99999237060547
#           @nameDef = 'M1_FOC2'
#         MONOC = 124.99951171875
#           @nameDef = 'MONOC'
#         MONTI = 14.498779296875
#           @nameDef = 'MONTI'
#         MONTR = 6.000244140625
#           @nameDef = 'MONTR'
#         MUTILT = 3.350128736201441e-06
#           @nameDef = 'MUTILT'
#         MU_X = 0.038081806153059006
#           @nameDef = 'MU_X'
#         MU_Y = -0.05641748756170273
#           @nameDef = 'MU_Y'
#         OMGM = 0.500244140625
#           @nameDef = 'OMGM'
#         OMGR = 75.0
#           @nameDef = 'OMGR'
#         OMGS = 10.0
#           @nameDef = 'OMGS'
#         PHIS = -120.0
#           @nameDef = 'PHIS'
#         RADCOLL = 0.0
#           @nameDef = 'RADCOLL'
#         TEMP = float32(5)
#           @nameDef = 'TEMP'
#         TTH1 = 2.9994330406188965
#           @nameDef = 'TTH1'
#         TTH2 = 22.998010635375977
#           @nameDef = 'TTH2'
#         TTH3 = 42.998958587646484
#           @nameDef = 'TTH3'
#         TTH4 = 62.99848556518555
#           @nameDef = 'TTH4'
#         TTHS = 10.0
#           @nameDef = 'TTHS'
#         T_DELTA = 0.0
#           @nameDef = 'T_DELTA'
#         T_MEAN = 0.0
#           @nameDef = 'T_MEAN'
#         T_REG = 26.14150047302246
#           @nameDef = 'T_REG'
#         T_SAM = 0.0
#           @nameDef = 'T_SAM'
#         YSD = 163.3000030517578
#           @nameDef = 'YSD'
#       RELA:CARdirectory
#         NYS = [2.560e+02 7.500e+01 1.277e-01]
#           @nameDef = 'NYS'
#         TTHS = [2.560e+02 1.280e+02 1.277e-01]
#           @nameDef = 'TTHS'
#         YSD = 0.0
#           @nameDef = 'YSD'
#       SETV:CARdirectory
#         STEP = 0
#           @nameDef = 'STEP'
#       SETVALUE:CARdirectory
#         STEP = int32(1442)
#           @nameDef = 'STEP'
#         TEMP = float32(1442)
#           @nameDef = 'TEMP'
#       SOF:CARdirectory
#         CHI1 = 0.0
#           @nameDef = 'CHI1'
#         CHI2 = 0.0
#           @nameDef = 'CHI2'
#         COLL15 = 0.0
#           @nameDef = 'COLL15'
#         COLL15T = 0.0
#           @nameDef = 'COLL15T'
#         COLL30 = 0.0
#           @nameDef = 'COLL30'
#         COLL30T = 0.0
#           @nameDef = 'COLL30T'
#         HTRANS = 0.0
#           @nameDef = 'HTRANS'
#         M1_FOC1 = 0.0
#           @nameDef = 'M1_FOC1'
#         M1_FOC2 = 0.0
#           @nameDef = 'M1_FOC2'
#         MONOC = 0.0
#           @nameDef = 'MONOC'
#         MONTI = 0.0
#           @nameDef = 'MONTI'
#         MONTR = 0.0
#           @nameDef = 'MONTR'
#         MUTILT = 0.0
#           @nameDef = 'MUTILT'
#         OMGM = 0.0
#           @nameDef = 'OMGM'
#         OMGR = 0.0
#           @nameDef = 'OMGR'
#         OMGS = -2.5
#           @nameDef = 'OMGS'
#         PHIS = -19.0
#           @nameDef = 'PHIS'
#         RADCOLL = 0.0
#           @nameDef = 'RADCOLL'
#         TTH1 = -0.03999999910593033
#           @nameDef = 'TTH1'
#         TTH2 = -0.009999999776482582
#           @nameDef = 'TTH2'
#         TTH3 = -0.029999999329447746
#           @nameDef = 'TTH3'
#         TTH4 = -0.019999999552965164
#           @nameDef = 'TTH4'
#         TTHS = 0.0
#           @nameDef = 'TTHS'
#       TMO:CARdirectory
#         CHI1 = 10
#           @nameDef = 'CHI1'
#         CHI2 = 10
#           @nameDef = 'CHI2'
#         COLL = 10
#           @nameDef = 'COLL'
#         COLL15 = 600
#           @nameDef = 'COLL15'
#         COLL15T = 10
#           @nameDef = 'COLL15T'
#         COLL30 = 600
#           @nameDef = 'COLL30'
#         COLL30T = 10
#           @nameDef = 'COLL30T'
#         HTRANS = 10
#           @nameDef = 'HTRANS'
#         M1_FOC1 = 10
#           @nameDef = 'M1_FOC1'
#         M1_FOC2 = 10
#           @nameDef = 'M1_FOC2'
#         MONOC = 10
#           @nameDef = 'MONOC'
#         MONTI = 10
#           @nameDef = 'MONTI'
#         MONTR = 10
#           @nameDef = 'MONTR'
#         MUTILT = 300
#           @nameDef = 'MUTILT'
#         OMGM = 10
#           @nameDef = 'OMGM'
#         OMGR = 60
#           @nameDef = 'OMGR'
#         OMGS = 60
#           @nameDef = 'OMGS'
#         PHIS = 120
#           @nameDef = 'PHIS'
#         RADCOLL = 10
#           @nameDef = 'RADCOLL'
#         TEMP = 6
#           @nameDef = 'TEMP'
#         TTH1 = 300
#           @nameDef = 'TTH1'
#         TTH2 = 300
#           @nameDef = 'TTH2'
#         TTH3 = 300
#           @nameDef = 'TTH3'
# ...
#         COLL15 = 0.009999999776482582
#           @nameDef = 'COLL15'
#         COLL15T = 0.004999999888241291
#           @nameDef = 'COLL15T'
#         COLL30 = 0.009999999776482582
#           @nameDef = 'COLL30'
#         COLL30T = 0.004999999888241291
#           @nameDef = 'COLL30T'
#         HTRANS = 0.0010000000474974513
#           @nameDef = 'HTRANS'
#         M1_FOC1 = 0.10000000149011612
#           @nameDef = 'M1_FOC1'
#         M1_FOC2 = 0.10000000149011612
#           @nameDef = 'M1_FOC2'
#         MONOC = 0.009999999776482582
#           @nameDef = 'MONOC'
#         MONTI = 0.10000000149011612
#           @nameDef = 'MONTI'
#         MONTR = 0.10000000149011612
#           @nameDef = 'MONTR'
#         MUTILT = 0.10000000149011612
#           @nameDef = 'MUTILT'
#         OMGM = 0.10000000149011612
#           @nameDef = 'OMGM'
#         OMGR = 0.10000000149011612
#           @nameDef = 'OMGR'
#         OMGS = 0.019999999552965164
#           @nameDef = 'OMGS'
#         PHIS = 0.009999999776482582
#           @nameDef = 'PHIS'
#         RADCOLL = 0.0010000000474974513
#           @nameDef = 'RADCOLL'
#         TEMP = 0.10000000149011612
#           @nameDef = 'TEMP'
#         TTH1 = 0.009999999776482582
#           @nameDef = 'TTH1'
#         TTH2 = 0.009999999776482582
#           @nameDef = 'TTH2'
#         TTH3 = 0.009999999776482582
#           @nameDef = 'TTH3'
#         TTH4 = 0.009999999776482582
#           @nameDef = 'TTH4'
#         TTHS = 0.009999999776482582
#           @nameDef = 'TTHS'
#       WINDA:CARdirectory
#         W1 = int16(4)
#           @nameDef = 'W1'
#         W2 = int16(4)
#           @nameDef = 'W2'
#         W3 = int16(4)
#           @nameDef = 'W3'
#         W4 = int16(4)
#           @nameDef = 'W4'
#       corbadevice = '[MONOC]...'
#         @file = '/datacollector/data/E2/carconfig/corba_e209426.dat'
#         @format = 'text'
#         @source_name = 'Corbadevice'
#       date = '18-Dec-2012, 19-Dec-2012'
#       device_log = '# TIMESTAMP        RUN   STEP        MON       TIM1     ...'
#         @file = '/datacollector/data/E2/caress/e209426_device.dat'
#         @format = 'text'
#         @source_name = 'CARDEV'
#       hardware_modules = ';+++++++++++++++++++++++++++++++++++++++++++++++++++++++...'
#         @file = '/datacollector/data/E2/carconfig/hardware_e209...'
#         @format = 'text'
#         @source_name = 'Hardware_modules'
#       protocol = '/hmi/caress/data/e209426.dat...'
#         @file = '/datacollector/data/E2/prt/e209426.prt'
#         @format = 'text'
#         @source_name = 'CARPRT'
#       protocol_time = '2012-12-18 23:36:55 (info) created new protocol file...'
#         @file = '/datacollector/data/E2/caress/e209426.car.log'
#         @format = 'text'
#         @source_name = 'CARLOG'
#       steps:NXpositioner
#         name = 'STEP'
#         set_value = 0
#         target_value = int32(1442)
#         value = 0
#       time = '23:43:32, 18:22:51'
#       unused:CARdirectory
#         MSH = 0
#         MU_X:NXpositioner
#           master_value = float32(1442)
#           name = 'MU_X'
#           position_prestart = 18.036670684814453
#             @units = 'degrees'
#           value = float32(1442)
#         MU_Y:NXpositioner
#           master_value = float32(1442)
#           name = 'MU_Y'
#           position_prestart = 17.915372848510742
#             @units = 'degrees'
#           value = float32(1442)
#         W1 = int16(4)
#         W2 = int16(4)
#         W3 = int16(4)
#         W4 = int16(4)
#         YSD:NXpositioner
#           RELA = 0.0
#           master_value = float32(1442)
#           name = 'YSD'
#           position_prestart = 163.3000030517578
#             @units = 'degrees'
#           value = float32(1442)
#     caress_file = '/hmi/caress/data/e209426.dat'
#     datacollector:CARdirectory
#       commandline = '/datacollector/application/bin/main -son -v=4 -of=/datac...'
#       config_file = '/datacollector/application/configuration/E2_inst.xml'
#       protocol = 'LOG: Building dependency tree......'
#       source_file = '/datacollector/application/configuration/E2_src.xml'
#       start = '2012-12-19T18:22:53L'
#       stop = '2012-12-19T18:26:57L'
#       version = 'Datacollector V 2.03 Release $$Rev: 2177 $$'
#     end_time = '2012-12-19T18:22:51L'
#     entry_identifier = '/hmi/caress/data/e209426.dat'
#     experiment_type = 'E2, A2, ADET, FLAT, TEMP'
#     monitor:NXmonitor
#       MON:NXpositioner
#         MM1 = 28000
#         master_value = int32(1442)
#         name = 'MON'
#         value = int32(1442)
#       data = int32(1442)
#         @signal = '1'
#       mode = 'monitor'
#       preset = 28000
#       sampled_fraction = 0.009999999776482582
#         @units = 'counts'
#     notes = 'tilt mu=18'
#     powder_diagram:NXdata
#       data = float64(1801)
#       errors = float64(1801)
#       monitor_sum = float64(1801)
#       polar_angle = float64(1801)
#       referenz_monitor = 0.0
#       sum_raw_data = float64(1801)
#       x = float64(1801)
#     program_name = 'Datacollector'
#     protocol:NXprocess
#       caress_commentaries:NXnote
#         data = 'tilt mu=18'
#         type = 'text/plain'
#     reciprocal_space:NXdata
#       data = float64(500x500)
#       errors = float64(500x500)
#       monitor_sum = float64(500x500)
#       raw_data = float64(500x500)
#       reference_monitor = 0.0
#       x = float64(500)
#       y = float64(500)
#     run_cycle = 9426
#     run_number = 9426
#     sample:NXsample
#       beam:NXbeam
#         distance = 0.30000001192092896
#           @units = 'm'
#           @unitsdef = 'm = meter'
#         final_wavelength = 1.2109999656677246
#           @units = 'angstrom'
#           @unitsdef = 'angstrom = decinanometer'
#         monochromator:NXcrystal
#           monochromator_changer:NXpositioner
#             Cu_Monochromator:NXcrystal
#               type = 'Cu'
#             Ge_Monochromator:NXcrystal
#               type = 'Ge'
#               wavelength = 1.2100000381469727
#                 @units = 'Angstroms'
#                 @unitsdef = 'Angstroms = angstrom = decinanometer'
#             PG_Monochromator:NXcrystal
#               focusing:CARdirectory
#                 motor_1:NXpositioner
#                   master_value = float32(1442)
#                   name = 'M1_FOC1'
#                   offset = 0.0
#                     @units = 'steps'
#                   position_prestart = 99.99999237060547
#                     @units = 'steps'
#                   soft_limit_max = 110.0
#                     @units = 'steps'
#                   soft_limit_min = -110.0
#                     @units = 'steps'
#                   timeout = 10
#                     @units = 's'
#                     @unitsdef = 's = second'
#                   tolerance = 0.10000000149011612
#                     @units = 'steps'
#                   value = float32(1442)
#                     @units = 'steps'
#                 motor_2:NXpositioner
#                   master_value = float32(1442)
#                   name = 'M1_FOC2'
#                   offset = 0.0
#                     @units = 'steps'
#                   position_prestart = 99.99999237060547
#                     @units = 'steps'
#                   soft_limit_max = 110.0
#                     @units = 'steps'
#                   soft_limit_min = -110.0
#                     @units = 'steps'
#                   timeout = 10
#                     @units = 's'
#                     @unitsdef = 's = second'
#                   tolerance = 0.10000000149011612
#                     @units = 'steps'
#                   value = float32(1442)
#                     @units = 'steps'
#               type = 'PG'
#               wavelength = 2.390000104904175
#                 @units = 'Angstroms'
#                 @unitsdef = 'Angstroms = angstrom = decinanometer'
#             master_value = float32(1442)
#             name = 'MONOC'
#             offset = 0.0
#               @units = 'steps'
#             position_prestart = 124.99951171875
#               @units = 'steps'
#             soft_limit_max = 250.0
#             soft_limit_min = -200.0
#             timeout = 10
#               @units = 's'
#               @unitsdef = 's = second'
#             tolerance = 0.009999999776482582
#               @units = 'steps'
#             value = float32(1442)
#               @units = 'steps'
#           omega:NXpositioner
#             master_value = float32(1442)
#             name = 'OMGM'
#             offset = 0.0
#               @units = 'degrees'
#             position_prestart = 0.500244140625
#               @units = 'degrees'
#             soft_limit_max = 30.0
#             soft_limit_min = 0.0
#             timeout = 10
#             tolerance = 0.10000000149011612
#             value = float32(1442)
#           tilting:NXpositioner
#             master_value = float32(1442)
#             name = 'MONTI'
#             offset = 0.0
#               @units = 'steps'
#             position_prestart = 14.498779296875
#               @units = 'steps'
#             soft_limit_max = 20.0
#               @units = 'steps'
#             soft_limit_min = 0.5
#               @units = 'steps'
#             timeout = 10
#               @units = 's'
#               @unitsdef = 's = second'
#             tolerance = 0.10000000149011612
#               @units = 'steps'
#             value = float32(1442)
#               @units = 'steps'
#           translation:NXpositioner
#             master_value = float32(1442)
#             name = 'MONTR'
#             offset = 0.0
#               @units = 'steps'
#             position_prestart = 6.000244140625
#               @units = 'steps'
#             soft_limit_max = 15.0
#               @units = 'steps'
#             soft_limit_min = 1.0
#               @units = 'steps'
#             timeout = 10
#               @units = 's'
#               @unitsdef = 's = second'
#             tolerance = 0.10000000149011612
#               @units = 'steps'
#             value = float32(1442)
#               @units = 'steps'
#           wavelength = 1.2109999656677246
#             @units = 'Angstroms'
#       chemical_formula = 'SAMPLE'
#       cross_cradle:CARcradle
#         CHI1:NXpositioner
#           master_value = float32(1442)
#           name = 'CHI1'
#           offset = 0.0
#             @units = 'degrees'
#           position_prestart = -17.999752044677734
#             @units = 'degrees'
#           soft_limit_max = 20.5
#           soft_limit_min = -20.0
#           timeout = 10
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         CHI2:NXpositioner
#           master_value = float32(1442)
#           name = 'CHI2'
#           offset = 0.0
#             @units = 'degrees'
#           position_prestart = -0.00024890899658203125
#             @units = 'degrees'
#           soft_limit_max = 20.0
#           soft_limit_min = -20.0
#           timeout = 10
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         OMGS:NXpositioner
#           master_value = float32(1442)
#           name = 'OMGS'
#           offset = -2.5
#             @units = 'degrees'
#           position_prestart = 10.015000343322754
#             @units = 'degrees'
#           soft_limit_max = 360.0
#           soft_limit_min = -360.0
#           timeout = 60
#           tolerance = 0.019999999552965164
#           value = float32(1442)
#         OMGX:NXpositioner
#           name = 'OMGX'
#         PHIS:NXpositioner
#           master_value = float32(1442)
#           name = 'PHIS'
#           offset = -19.0
#             @units = 'degrees'
#           position_prestart = -119.9990005493164
#             @units = 'degrees'
#           soft_limit_max = 360.0
#           soft_limit_min = -360.0
#           timeout = 120
#           tolerance = 0.009999999776482582
#           value = float32(1442)
#         chi_sample1 = float32(1442)
#           @lower_limit = -20.0
#           @name = 'CHI1'
#           @offset = 0.0
#           @timeout = 10
#           @tolerance = 0.009999999776482582
#           @units = 'degree'
#           @unitsdef = 'degree = angular_degree'
#           @upper_limit = 20.5
#         chi_sample2 = float32(1442)
#           @lower_limit = -20.0
#           @name = 'CHI2'
#           @offset = 0.0
#           @timeout = 10
#           @tolerance = 0.009999999776482582
#           @units = 'degree'
#           @unitsdef = 'degree = angular_degree'
#           @upper_limit = 20.0
#         name = 'Standard E2'
#         omega_sample = float32(1442)
#           @lower_limit = -360.0
#           @name = 'OMGS'
#           @offset = -2.5
#           @timeout = 60
#           @tolerance = 0.019999999552965164
#           @units = 'degree'
#           @unitsdef = 'degree = angular_degree'
#           @upper_limit = 360.0
#         phi_sample = float32(1442)
#           @lower_limit = -360.0
#           @name = 'PHIS'
#           @offset = 0.0
#           @timeout = 120
#           @tolerance = 0.009999999776482582
#           @units = 'degree'
#           @unitsdef = 'degree = angular_degree'
#           @upper_limit = 360.0
#         type = 'cross'
#       hkl:CARdirectory
#         E:NXpositioner
#           name = 'E'
#         h:NXpositioner
#           name = 'H'
#         k:NXpositioner
#           name = 'K'
#         l:NXpositioner
#           name = 'L'
#       name = 'SAMPLE'
#       orientation_matrix = float32(9)
#       rotation_angle = float64(1442)
#         @name = 'entry_1/sample/cross_cradle/phi_sample'
#         @units = 'degree'
#         @unitsdef = 'degree = angular_degree'
#       sample_environment_control:CARdirectory
#         COLDTRAP:NXpositioner
#           name = 'COLDTRAP'
#         HE:NXpositioner
#           name = 'HE'
#         LN2:NXpositioner
#           name = 'LN2'
#         MAGF:NXpositioner
#           name = 'MAGF'
#         TEMP:NXpositioner
#           name = 'TEMP'
#           position_prestart = float32(5)
#             @units = 'degrees'
#           soft_limit_max = 2000.0
#           soft_limit_min = 0.0
#           target_value = float32(1442)
#           timeout = 6
#           tolerance = 0.10000000149011612
#         T_DELTA:NXpositioner
#           master_value = float32(1442)
#           name = 'T_DELTA'
#           position_prestart = 0.0
#             @units = 'degrees'
#           value = float32(1442)
#         T_MEAN:NXpositioner
#           master_value = float32(1442)
#           name = 'T_MEAN'
#           position_prestart = 0.0
#             @units = 'degrees'
#           value = float32(1442)
#         T_REG:NXpositioner
#           master_value = float32(1442)
#           name = 'T_REG'
#           position_prestart = 27.056299209594727
#             @units = 'degrees'
#           value = float32(1442)
#         T_SAM:NXpositioner
#           name = 'T_SAM'
#           position_prestart = 0.0
#             @units = 'degrees'
#           protocol_value_begin = float32(1442)
#           protocol_value_end = float32(1442)
#           value = float32(1442)
#         delta_temperature = float32(1442)
#           @units = 'kelvin'
#           @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#         mean_temperature = float32(1442)
#           @units = 'kelvin'
#           @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#         regulation_temperature = float32(1442)
#           @units = 'kelvin'
#           @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#         sample_temperature = float32(1442)
#           @units = 'kelvin'
#           @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#       sample_environment_group:NXuser
#         address = 'Glienicker Str. 100, D-14109 Berlin'
#         affiliation = 'HMI Berlin'
#         email = 'michael.meissner@hmi.de'
#         name = 'Prof. Dr. Michael Meissner'
#         role = 'Group Leader  Sample Environment'
#         telephone_number = '+49 30 8062 2204'
#       temperature = float32(1442)
#         @units = 'kelvin'
#         @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#       unit_cell = float32(6)
#         @units = 'angstrom and degree'
#         @unitsdef = 'angstrom = decinanometer    and   degree = ang...'
#     start_time = '2012-12-18T23:43:32L'
#     step_number = 0
#     timer:NXmonitor
#       TIM1:NXpositioner
#         master_value = int32(1442)
#         name = 'TIM1'
#         value = int32(1442)
#       TIM2:NXpositioner
#         master_value = int32(1442)
#         name = 'TIM2'
#         value = int32(1442)
#       backup:NXmonitor
#         data = int32(1442)
#         mode = 'timer'
#       data = int32(1442)
#         @signal = '1'
#       mode = 'timer'
#     title = 'D2O SC CC PHY-01-2836-EF'
#     user_caress:NXuser
#       name = 'Klemke'
#       role = 'Caress Main User'

# %% [markdown]
# Parse the structure/ extract specific elements

# %%
print(a.entry_1.tree)
# Out:
# entry_1:NXentry
#   E2:NXinstrument
#     ADET1:NXdetector
#       active_window = int16(4)
#       board_parameter:CARdirectory
#         DSP_buffer = float64(1442)
#           @description = 'Size of DSP buffer'
#           @units = 'kWords'
#         RAW_mode = float64(1442)
#           @description = 'RAW Mode on(1)/off(0)'
#         TDC_trigger_latency = float64(1442)
#           @description = '106 approx. 4.5 ns'
#         TDL_X_DSP = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_X_FPGA = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_Y_DSP = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_Y_FPGA = float64(1442)
#           @description = 'TDC'
#           @units = 'channel'
#         board_parameter_array = float64(1442x30)
#         delta_TDL_X_DSP = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_X_FPGA = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_Y_DSP = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_Y_FPGA = float64(1442)
#           @description = 'TDC'
#           @units = 'channel'
#         f_resolution = float64(1442)
#           @description = 'frequency resolution TDC'
#           @units = 'ps'
#         hist_1D = float64(1442)
#           @description = 'size of dead time histogram'
#         hist_2D0 = float64(1442)
#         hist_2D1 = float64(1442)
#         latency = float64(1442)
#           @description = 'Latency'
#           @units = 'ns'
#         resolution = float64(1442)
#           @description = 'TDC resolution'
#           @units = 'ps'
#         standard_1D_DSP_size = float64(1442)
#           @description = 'size of dead time sprectra'
#           @units = 'byte'
#         test_generator_frequency_coefficient = float64(1442)
#         trigger_window = float64(1442)
#           @description = 'TDC trigger window'
#           @units = 'ns'
#         unused:CARdirectory
#           ADC_threshold_level = float64(1442)
#           TOF_mode = float64(1442)
#           TOF_number_of_time_channels = float64(1442)
#           TOF_time_channel_width = float64(1442)
#           TOF_window_delay_register = float64(1442)
#           bits_shifted_in_pos = float64(1442)
#           enable_test_generation = float64(1442)
#           look_up_table_file = float64(1442)
#         x_lenghth = float64(1442)
#           @description = 'histogram channels'
#           @units = 'pixel'
#         y_lenghth = float64(1442)
#           @description = 'histogram channel'
#           @units = 'pixel'
#       data = int32(1442x256x256)
#         @axes = '[x,y]'
#         @units = 'number'
#       dead_time_information:CARdirectory
#         DSP_Input = float64(1442)
#         DSP_NoHeader = float64(1442)
#         DSP_bad_X_sum = float64(1442)
#         DSP_bad_Y_sum = float64(1442)
#         DSP_dead_time = float64(1442)
#         DSP_lost_x1 = float64(1442)
#         DSP_lost_x2 = float64(1442)
#         DSP_lost_y1 = float64(1442)
#         DSP_lost_y2 = float64(1442)
#         DSP_refused = float64(1442)
#         FPGA_bad_X_sum = float64(1442)
#         FPGA_bad_Y_sum = float64(1442)
#         FPGA_discard = float64(1442)
#           @description = 'sum of all bad events'
#         FPGA_lost_starts = float64(1442)
#         FPGA_lost_tr = float64(1442)
#         FPGA_lost_x1 = float64(1442)
#         FPGA_lost_x2 = float64(1442)
#         FPGA_lost_y1 = float64(1442)
#         FPGA_lost_y2 = float64(1442)
#         PC_Input = float64(1442)
#         PC_NoHeader = float64(1442)
#         PC_bad_X_sum = float64(1442)
#         PC_bad_Y_sum = float64(1442)
#         PC_lost_x1 = float64(1442)
#         PC_lost_x2 = float64(1442)
#         PC_lost_y1 = float64(1442)
#         PC_lost_y2 = float64(1442)
#         accepted = float64(1442)
#         dead_time_array = float64(1442x30)
#         starts = float64(1442)
#           @description = 'all start events; ratio of start to FPGA_disca...'
#         stored = float64(1442)
#       description = 'Denex 00?'
#       detector_house:NXpositioner
#         description = 'Position of the detector housing. Additional to the indi...'
#         master_value = float32(1442)
#         name = 'TTHS'
#         offset = 0.0
#           @units = 'degrees'
#         position_prestart = 10.0
#           @units = 'degrees'
#         soft_limit_max = 25.0
#         soft_limit_min = -5.0
#         timeout = 300
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       detector_number = 1
#       discard_event_ratio = float64(1442)
#       distance = float32(1442)
#       efficiency:NXdata
#         comment = '...'
#         efficiency = float64(256x256)
#           @file = '/datacollector/data/E2/xml/E2_Eff.xml'
#           @format = 'xml'
#           @source_name = 'EffXML'
#       factor = float64(1442x256x256)
#       gas_pressure = 6.0
#         @mixture = '3He: 4.8 bar and CF4: 1.2 bar'
#         @units = 'bars'
#       histogramming:CARdirectory
#         H_X1-X2_User_1D1_dsp_after_run = int32(1442x256)
#         H_X1-X2_Y1-Y2_User_2D11_dsp_run = int32(1442x256x256)
#         H_Y1-Y2_User_1D2_dsp_after_run = int32(1442x256)
#         X1-X2_Y1-Y2_dsp = int32(1442x256x256)
#         X1pX2_dsp = int32(1442x10000)
#         Y1pY2_dsp = int32(1442x10000)
#       integral = int32(1442)
#       local_name = 'ADET1'
#       logs:CARdirectory
#         root_log = '                          ------------------------------...'
#           @file = '/datacollector/data/E2/rootlogs/e209418_Det1.r...'
#           @format = 'text'
#           @source_name = 'Log_det1'
#         scan_log = '2012-12-10 12:00:33     4    40.44        3459       271...'
#           @file = '/datacollector/data/E2/rootlogs/Caress_Scans_e...'
#           @format = 'text'
#           @source_name = 'Carscan_det1'
#       polar_angle = float64(1442)
#       position:NXpositioner
#         description = 'Position of the 1st detector in the housing. Additional ...'
#         master_value = float32(1442)
#         name = 'TTH1'
#         offset = -0.03999999910593033
#           @units = 'degrees'
#         position_prestart = 2.9994330406188965
#           @units = 'degrees'
#         soft_limit_max = 25.399999618530273
#         soft_limit_min = 2.9000000953674316
#         timeout = 300
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       translation:NXpositioner
#         description = 'Translation of the detectorhouse.'
#         master_value = float32(1442)
#         name = 'HTRANS'
#         offset = 0.0
#           @units = 'mm'
#         position_prestart = -0.692307710647583
#           @units = 'mm'
#         soft_limit_max = 150.0
#         soft_limit_min = -150.0
#         timeout = 10
#         tolerance = 0.0010000000474974513
#         value = float32(1442)
#       type = 'He3'
#       x_offset = [2.560e+02 1.280e+02 1.277e-01]
#         @axis = '3'
#         @primary = '1'
#         @units = 'pixel'
#       x_pixel_number = 256.0
#       x_pixel_offset = 128.0
#       x_pixel_size = 0.12770000100135803
#       y_offset = [2.560e+02 7.500e+01 1.277e-01]
#         @axis = '4'
#         @primary = '1'
#         @units = 'pixel'
#       y_pixel_number = 256.0
#       y_pixel_offset = 75.0
#       y_pixel_size = 0.12770000100135803
#     ADET2:NXdetector
#       active_window = int16(4)
#       board_parameter:CARdirectory
#         DSP_buffer = float64(1442)
#           @description = 'Size of DSP buffer'
#           @units = 'kWords'
#         RAW_mode = float64(1442)
#           @description = 'RAW Mode on(1)/off(0)'
#         TDC_trigger_latency = float64(1442)
#           @description = '106 approx. 4.5 ns'
#         TDL_X_DSP = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_X_FPGA = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_Y_DSP = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_Y_FPGA = float64(1442)
#           @description = 'TDC'
#           @units = 'channel'
#         board_parameter_array = float64(1442x30)
#         delta_TDL_X_DSP = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_X_FPGA = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_Y_DSP = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_Y_FPGA = float64(1442)
#           @description = 'TDC'
#           @units = 'channel'
#         f_resolution = float64(1442)
#           @description = 'frequency resolution TDC'
#           @units = 'ps'
#         hist_1D = float64(1442)
#           @description = 'size of dead time histogram'
#         hist_2D0 = float64(1442)
#         hist_2D1 = float64(1442)
#         latency = float64(1442)
#           @description = 'Latency'
#           @units = 'ns'
#         resolution = float64(1442)
#           @description = 'TDC resolution'
#           @units = 'ps'
#         standard_1D_DSP_size = float64(1442)
#           @description = 'size of dead time sprectra'
#           @units = 'byte'
#         test_generator_frequency_coefficient = float64(1442)
#         trigger_window = float64(1442)
#           @description = 'TDC trigger window'
#           @units = 'ns'
#         unused:CARdirectory
#           ADC_threshold_level = float64(1442)
#           TOF_mode = float64(1442)
#           TOF_number_of_time_channels = float64(1442)
#           TOF_time_channel_width = float64(1442)
#           TOF_window_delay_register = float64(1442)
#           bits_shifted_in_pos = float64(1442)
#           enable_test_generation = float64(1442)
#           look_up_table_file = float64(1442)
#         x_lenghth = float64(1442)
#           @description = 'histogram channels'
#           @units = 'pixel'
#         y_lenghth = float64(1442)
#           @description = 'histogram channel'
#           @units = 'pixel'
#       data = int32(1442x256x256)
#         @axes = '[x,y]'
#         @units = 'number'
#       dead_time_information:CARdirectory
#         DSP_Input = float64(1442)
#         DSP_NoHeader = float64(1442)
#         DSP_bad_X_sum = float64(1442)
#         DSP_bad_Y_sum = float64(1442)
#         DSP_dead_time = float64(1442)
#         DSP_lost_x1 = float64(1442)
#         DSP_lost_x2 = float64(1442)
#         DSP_lost_y1 = float64(1442)
#         DSP_lost_y2 = float64(1442)
#         DSP_refused = float64(1442)
#         FPGA_bad_X_sum = float64(1442)
#         FPGA_bad_Y_sum = float64(1442)
#         FPGA_discard = float64(1442)
#           @description = 'sum of all bad events'
#         FPGA_lost_starts = float64(1442)
#         FPGA_lost_tr = float64(1442)
#         FPGA_lost_x1 = float64(1442)
#         FPGA_lost_x2 = float64(1442)
#         FPGA_lost_y1 = float64(1442)
#         FPGA_lost_y2 = float64(1442)
#         PC_Input = float64(1442)
#         PC_NoHeader = float64(1442)
#         PC_bad_X_sum = float64(1442)
#         PC_bad_Y_sum = float64(1442)
#         PC_lost_x1 = float64(1442)
#         PC_lost_x2 = float64(1442)
#         PC_lost_y1 = float64(1442)
#         PC_lost_y2 = float64(1442)
#         accepted = float64(1442)
#         dead_time_array = float64(1442x30)
#         starts = float64(1442)
#           @description = 'all start events; ratio of start to FPGA_disca...'
#         stored = float64(1442)
#       description = 'Denex 00?'
#       detector_house:NXpositioner
#         description = 'Position of the detector housing. Additional to the indi...'
#         master_value = float32(1442)
#         name = 'TTHS'
#         offset = 0.0
#           @units = 'degrees'
#         position_prestart = 10.0
#           @units = 'degrees'
#         soft_limit_max = 25.0
#         soft_limit_min = -5.0
#         timeout = 300
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       detector_number = 2
#       discard_event_ratio = float64(1442)
#       distance = float32(1442)
#       efficiency:NXdata
#         comment = '...'
#         efficiency = float64(256x256)
#           @file = '/datacollector/data/E2/xml/E2_Eff.xml'
#           @format = 'xml'
#           @source_name = 'EffXML'
#       factor = float64(1442x256x256)
#       gas_pressure = 6.0
#         @mixture = '3He: 4.8 bar and CF4: 1.2 bar'
#         @units = 'bars'
#       histogramming:CARdirectory
#         H_X1-X2_User_1D1_dsp_after_run = int32(1442x256)
#         H_X1-X2_Y1-Y2_User_2D11_dsp_run = int32(1442x256x256)
#         H_Y1-Y2_User_1D2_dsp_after_run = int32(1442x256)
#         X1-X2_Y1-Y2_dsp = int32(1442x256x256)
#         X1pX2_dsp = int32(1442x10000)
#         Y1pY2_dsp = int32(1442x10000)
#       integral = int32(1442)
#       local_name = 'ADET2'
#       logs:CARdirectory
#         root_log = '                          ------------------------------...'
#           @file = '/datacollector/data/E2/rootlogs/e209418_Det2.r...'
#           @format = 'text'
#           @source_name = 'Log_det2'
#         scan_log = '2012-12-10 12:00:32     4    40.91        3291       290...'
#           @file = '/datacollector/data/E2/rootlogs/Caress_Scans_e...'
#           @format = 'text'
#           @source_name = 'Carscan_det2'
#       polar_angle = float64(1442)
#       position:NXpositioner
#         description = 'Position of the 2nd detector in the housing. Additional ...'
#         master_value = float32(1442)
#         name = 'TTH2'
#         offset = -0.009999999776482582
#           @units = 'degrees'
#         position_prestart = 22.998010635375977
#           @units = 'degrees'
#         soft_limit_max = 41.5
#         soft_limit_min = 18.899999618530273
#         timeout = 300
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       translation:NXpositioner
#         description = 'Translation of the detectorhouse.'
#         master_value = float32(1442)
#         name = 'HTRANS'
#         offset = 0.0
#           @units = 'mm'
#         position_prestart = -0.692307710647583
#           @units = 'mm'
#         soft_limit_max = 150.0
#         soft_limit_min = -150.0
#         timeout = 10
#         tolerance = 0.0010000000474974513
#         value = float32(1442)
#       type = 'He3'
#       x_offset = [2.560e+02 1.280e+02 1.277e-01]
#         @axis = '3'
#         @primary = '1'
#         @units = 'pixel'
#       x_pixel_number = 256.0
#       x_pixel_offset = 128.0
#       x_pixel_size = 0.12200000137090683
#       y_offset = [2.560e+02 7.500e+01 1.277e-01]
#         @axis = '4'
#         @primary = '1'
#         @units = 'pixel'
#       y_pixel_number = 256.0
#       y_pixel_offset = 75.0
#       y_pixel_size = 0.12200000137090683
#     ADET3:NXdetector
#       active_window = int16(4)
#       board_parameter:CARdirectory
#         DSP_buffer = float64(1442)
#           @description = 'Size of DSP buffer'
#           @units = 'kWords'
#         RAW_mode = float64(1442)
#           @description = 'RAW Mode on(1)/off(0)'
#         TDC_trigger_latency = float64(1442)
#           @description = '106 approx. 4.5 ns'
#         TDL_X_DSP = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_X_FPGA = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_Y_DSP = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_Y_FPGA = float64(1442)
#           @description = 'TDC'
#           @units = 'channel'
#         board_parameter_array = float64(1442x30)
#         delta_TDL_X_DSP = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_X_FPGA = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_Y_DSP = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_Y_FPGA = float64(1442)
#           @description = 'TDC'
#           @units = 'channel'
#         f_resolution = float64(1442)
#           @description = 'frequency resolution TDC'
#           @units = 'ps'
#         hist_1D = float64(1442)
#           @description = 'size of dead time histogram'
#         hist_2D0 = float64(1442)
#         hist_2D1 = float64(1442)
#         latency = float64(1442)
#           @description = 'Latency'
#           @units = 'ns'
#         resolution = float64(1442)
#           @description = 'TDC resolution'
#           @units = 'ps'
#         standard_1D_DSP_size = float64(1442)
#           @description = 'size of dead time sprectra'
#           @units = 'byte'
#         test_generator_frequency_coefficient = float64(1442)
#         trigger_window = float64(1442)
#           @description = 'TDC trigger window'
#           @units = 'ns'
#         unused:CARdirectory
#           ADC_threshold_level = float64(1442)
#           TOF_mode = float64(1442)
#           TOF_number_of_time_channels = float64(1442)
#           TOF_time_channel_width = float64(1442)
#           TOF_window_delay_register = float64(1442)
#           bits_shifted_in_pos = float64(1442)
#           enable_test_generation = float64(1442)
#           look_up_table_file = float64(1442)
#         x_lenghth = float64(1442)
#           @description = 'histogram channels'
#           @units = 'pixel'
#         y_lenghth = float64(1442)
#           @description = 'histogram channel'
#           @units = 'pixel'
#       data = int32(1442x256x256)
#         @axes = '[x,y]'
#         @units = 'number'
#       dead_time_information:CARdirectory
#         DSP_Input = float64(1442)
#         DSP_NoHeader = float64(1442)
#         DSP_bad_X_sum = float64(1442)
#         DSP_bad_Y_sum = float64(1442)
#         DSP_dead_time = float64(1442)
#         DSP_lost_x1 = float64(1442)
#         DSP_lost_x2 = float64(1442)
#         DSP_lost_y1 = float64(1442)
#         DSP_lost_y2 = float64(1442)
#         DSP_refused = float64(1442)
#         FPGA_bad_X_sum = float64(1442)
#         FPGA_bad_Y_sum = float64(1442)
#         FPGA_discard = float64(1442)
#           @description = 'sum of all bad events'
#         FPGA_lost_starts = float64(1442)
#         FPGA_lost_tr = float64(1442)
#         FPGA_lost_x1 = float64(1442)
#         FPGA_lost_x2 = float64(1442)
#         FPGA_lost_y1 = float64(1442)
#         FPGA_lost_y2 = float64(1442)
#         PC_Input = float64(1442)
#         PC_NoHeader = float64(1442)
#         PC_bad_X_sum = float64(1442)
#         PC_bad_Y_sum = float64(1442)
#         PC_lost_x1 = float64(1442)
#         PC_lost_x2 = float64(1442)
#         PC_lost_y1 = float64(1442)
#         PC_lost_y2 = float64(1442)
#         accepted = float64(1442)
#         dead_time_array = float64(1442x30)
#         starts = float64(1442)
#           @description = 'all start events; ratio of start to FPGA_disca...'
#         stored = float64(1442)
#       description = 'Denex 00?'
#       detector_house:NXpositioner
#         description = 'Position of the detector housing. Additional to the indi...'
#         master_value = float32(1442)
#         name = 'TTHS'
#         offset = 0.0
#           @units = 'degrees'
#         position_prestart = 10.0
#           @units = 'degrees'
#         soft_limit_max = 25.0
#         soft_limit_min = -5.0
#         timeout = 300
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       detector_number = 3
#       discard_event_ratio = float64(1442)
#       distance = float32(1442)
#       efficiency:NXdata
#         comment = '...'
#         efficiency = float64(256x256)
#           @file = '/datacollector/data/E2/xml/E2_Eff.xml'
#           @format = 'xml'
#           @source_name = 'EffXML'
#       factor = float64(1442x256x256)
#       gas_pressure = 6.0
#         @mixture = '3He: 4.8 bar and CF4: 1.2 bar'
#         @units = 'bars'
#       histogramming:CARdirectory
#         H_X1-X2_User_1D1_dsp_after_run = int32(1442x256)
#         H_X1-X2_Y1-Y2_User_2D11_dsp_run = int32(1442x256x256)
#         H_Y1-Y2_User_1D2_dsp_after_run = int32(1442x256)
#         X1-X2_Y1-Y2_dsp = int32(1442x256x256)
#         X1pX2_dsp = int32(1442x10000)
#         Y1pY2_dsp = int32(1442x10000)
#       integral = int32(1442)
#       local_name = 'ADET3'
#       logs:CARdirectory
#         root_log = '                          ------------------------------...'
#           @file = '/datacollector/data/E2/rootlogs/e209418_Det3.r...'
#           @format = 'text'
#           @source_name = 'Log_det3'
#         scan_log = '-----------------   E2_Detector_3_Commissioning_run9385_...'
#           @file = '/datacollector/data/E2/rootlogs/Caress_Scans_e...'
#           @format = 'text'
#           @source_name = 'Carscan_det3'
#       polar_angle = float64(1442)
#       position:NXpositioner
#         description = 'Position of the 3rd detector in the housing. Additional ...'
#         master_value = float32(1442)
#         name = 'TTH3'
#         offset = -0.029999999329447746
#           @units = 'degrees'
#         position_prestart = 42.998958587646484
#           @units = 'degrees'
#         soft_limit_max = 57.5
#         soft_limit_min = 34.900001525878906
#         timeout = 300
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       translation:NXpositioner
#         description = 'Translation of the detectorhouse.'
#         master_value = float32(1442)
#         name = 'HTRANS'
#         offset = 0.0
#           @units = 'mm'
#         position_prestart = -0.692307710647583
#           @units = 'mm'
#         soft_limit_max = 150.0
#         soft_limit_min = -150.0
#         timeout = 10
#         tolerance = 0.0010000000474974513
#         value = float32(1442)
#       type = 'He3'
#       x_offset = [2.560e+02 1.280e+02 1.277e-01]
#         @axis = '3'
#         @primary = '1'
#         @units = 'pixel'
#       x_pixel_number = 256.0
#       x_pixel_offset = 128.0
#       x_pixel_size = 0.12770000100135803
#       y_offset = [2.560e+02 7.500e+01 1.277e-01]
#         @axis = '4'
#         @primary = '1'
#         @units = 'pixel'
#       y_pixel_number = 256.0
#       y_pixel_offset = 75.0
#       y_pixel_size = 0.12770000100135803
#     ADET4:NXdetector
#       active_window = int16(4)
#       board_parameter:CARdirectory
#         DSP_buffer = float64(1442)
#           @description = 'Size of DSP buffer'
#           @units = 'kWords'
#         RAW_mode = float64(1442)
#           @description = 'RAW Mode on(1)/off(0)'
#         TDC_trigger_latency = float64(1442)
#           @description = '106 approx. 4.5 ns'
#         TDL_X_DSP = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_X_FPGA = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_Y_DSP = float64(1442)
#           @description = 'Peak center'
#           @units = 'channel'
#         TDL_Y_FPGA = float64(1442)
#           @description = 'TDC'
#           @units = 'channel'
#         board_parameter_array = float64(1442x30)
#         delta_TDL_X_DSP = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_X_FPGA = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_Y_DSP = float64(1442)
#           @description = 'Peak width'
#           @units = 'channel'
#         delta_TDL_Y_FPGA = float64(1442)
#           @description = 'TDC'
#           @units = 'channel'
#         f_resolution = float64(1442)
#           @description = 'frequency resolution TDC'
#           @units = 'ps'
#         hist_1D = float64(1442)
#           @description = 'size of dead time histogram'
#         hist_2D0 = float64(1442)
#         hist_2D1 = float64(1442)
#         latency = float64(1442)
#           @description = 'Latency'
#           @units = 'ns'
#         resolution = float64(1442)
#           @description = 'TDC resolution'
#           @units = 'ps'
#         standard_1D_DSP_size = float64(1442)
#           @description = 'size of dead time sprectra'
#           @units = 'byte'
#         test_generator_frequency_coefficient = float64(1442)
#         trigger_window = float64(1442)
#           @description = 'TDC trigger window'
#           @units = 'ns'
#         unused:CARdirectory
#           ADC_threshold_level = float64(1442)
#           TOF_mode = float64(1442)
#           TOF_number_of_time_channels = float64(1442)
#           TOF_time_channel_width = float64(1442)
#           TOF_window_delay_register = float64(1442)
#           bits_shifted_in_pos = float64(1442)
#           enable_test_generation = float64(1442)
#           look_up_table_file = float64(1442)
#         x_lenghth = float64(1442)
#           @description = 'histogram channels'
#           @units = 'pixel'
#         y_lenghth = float64(1442)
#           @description = 'histogram channel'
#           @units = 'pixel'
#       data = int32(1442x256x256)
#         @axes = '[x,y]'
#         @units = 'number'
#       dead_time_information:CARdirectory
#         DSP_Input = float64(1442)
#         DSP_NoHeader = float64(1442)
#         DSP_bad_X_sum = float64(1442)
#         DSP_bad_Y_sum = float64(1442)
#         DSP_dead_time = float64(1442)
#         DSP_lost_x1 = float64(1442)
#         DSP_lost_x2 = float64(1442)
#         DSP_lost_y1 = float64(1442)
#         DSP_lost_y2 = float64(1442)
#         DSP_refused = float64(1442)
#         FPGA_bad_X_sum = float64(1442)
#         FPGA_bad_Y_sum = float64(1442)
#         FPGA_discard = float64(1442)
#           @description = 'sum of all bad events'
#         FPGA_lost_starts = float64(1442)
#         FPGA_lost_tr = float64(1442)
#         FPGA_lost_x1 = float64(1442)
#         FPGA_lost_x2 = float64(1442)
#         FPGA_lost_y1 = float64(1442)
#         FPGA_lost_y2 = float64(1442)
#         PC_Input = float64(1442)
#         PC_NoHeader = float64(1442)
#         PC_bad_X_sum = float64(1442)
#         PC_bad_Y_sum = float64(1442)
#         PC_lost_x1 = float64(1442)
#         PC_lost_x2 = float64(1442)
#         PC_lost_y1 = float64(1442)
#         PC_lost_y2 = float64(1442)
#         accepted = float64(1442)
#         dead_time_array = float64(1442x30)
#         starts = float64(1442)
#           @description = 'all start events; ratio of start to FPGA_disca...'
#         stored = float64(1442)
#       description = 'Denex 00?'
#       detector_house:NXpositioner
#         description = 'Position of the detector housing. Additional to the indi...'
#         master_value = float32(1442)
#         name = 'TTHS'
#         offset = 0.0
#           @units = 'degrees'
#         position_prestart = 10.0
#           @units = 'degrees'
#         soft_limit_max = 25.0
#         soft_limit_min = -5.0
#         timeout = 300
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       detector_number = 4
#       discard_event_ratio = float64(1442)
#       distance = float32(1442)
#       efficiency:NXdata
#         comment = '...'
#         efficiency = float64(256x256)
#           @file = '/datacollector/data/E2/xml/E2_Eff.xml'
#           @format = 'xml'
#           @source_name = 'EffXML'
#       factor = float64(1442x256x256)
#       gas_pressure = 6.0
#         @mixture = '3He: 4.8 bar and CF4: 1.2 bar'
#         @units = 'bars'
#       histogramming:CARdirectory
#         H_X1-X2_User_1D1_dsp_after_run = int32(1442x256)
#         H_X1-X2_Y1-Y2_User_2D11_dsp_run = int32(1442x256x256)
#         H_Y1-Y2_User_1D2_dsp_after_run = int32(1442x256)
#         X1-X2_Y1-Y2_dsp = int32(1442x256x256)
#         X1pX2_dsp = int32(1442x10000)
#         Y1pY2_dsp = int32(1442x10000)
#       integral = int32(1442)
#       local_name = 'ADET4'
#       logs:CARdirectory
#         root_log = '                          ------------------------------...'
#           @file = '/datacollector/data/E2/rootlogs/e209418_Det4.r...'
#           @format = 'text'
#           @source_name = 'Log_det4'
#         scan_log = '-----------------   E2_Detector_4_Commissioning_run9385_...'
#           @file = '/datacollector/data/E2/rootlogs/Caress_Scans_e...'
#           @format = 'text'
#           @source_name = 'Carscan_det4'
#       polar_angle = float64(1442)
#       position:NXpositioner
#         description = 'Position of the 4th detector in the housing. Additional ...'
#         master_value = float32(1442)
#         name = 'TTH4'
#         offset = -0.019999999552965164
#           @units = 'degrees'
#         position_prestart = 62.99848556518555
#           @units = 'degrees'
#         soft_limit_max = 73.5
#         soft_limit_min = 50.900001525878906
#         timeout = 300
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       translation:NXpositioner
#         description = 'Translation of the detectorhouse.'
#         master_value = float32(1442)
#         name = 'HTRANS'
#         offset = 0.0
#           @units = 'mm'
#         position_prestart = -0.692307710647583
#           @units = 'mm'
#         soft_limit_max = 150.0
#         soft_limit_min = -150.0
#         timeout = 10
#         tolerance = 0.0010000000474974513
#         value = float32(1442)
#       type = 'He3'
#       x_offset = [2.560e+02 1.280e+02 1.277e-01]
#         @axis = '3'
#         @primary = '1'
#         @units = 'pixel'
#       x_pixel_number = 256.0
#       x_pixel_offset = 128.0
#       x_pixel_size = 0.12770000100135803
#       y_offset = [2.560e+02 7.500e+01 1.277e-01]
#         @axis = '4'
#         @primary = '1'
#         @units = 'pixel'
#       y_pixel_number = 256.0
#       y_pixel_offset = 75.0
#       y_pixel_size = 0.12770000100135803
#     BER_II:NXsource
#       distance = 3.0
#         @units = 'm'
#         @unitsdef = 'm = meter'
#       name = 'BER II @ HMI Berlin, Germany'
#       power = 0.0
#         @units = 'MW'
#         @unitsdef = 'MW = 1e6 watt'
#       probe = 'neutron'
#       type = 'Reactor Neutron Source'
#     beamstop:NXbeam_stop
#       distance_to_detector = 300.0
#         @units = 'm'
#         @unitsdef = 'm = meter'
#     collimator_radial:NXcollimator
#       absorbing_material = 'Gadulinium Oxide on Aluminium plates'
#       adjustment = float32(1442)
#         @lower_limit = -110.0
#         @offset = 0.0
#         @timeout = 60
#         @tolerance = 0.10000000149011612
#         @units = 'steps'
#         @upper_limit = 110.0
#       alignment:NXpositioner
#         master_value = float32(1442)
#         name = 'OMGR'
#         offset = 0.0
#           @units = 'degrees'
#         position_prestart = 75.0
#           @units = 'degrees'
#         soft_limit_max = 110.0
#         soft_limit_min = -110.0
#         timeout = 60
#         tolerance = 0.10000000149011612
#         value = float32(1442)
#       blade_spacing = 0.20000000298023224
#         @units = 'arcmin'
#         @unitsdef = 'arcmin = arcminute'
#       blade_thickness = 0.5
#         @units = '10^-3 meter'
#       frequency = float64(1442)
#         @units = 'Hz'
#         @unitsdef = 'Hz = hertz = 1/second'
#       motor:NXpositioner
#         factor = 0.0010000000474974513
#         master_value = float32(1442)
#         name = 'RADCOLL'
#         offset = 0.0
#         position_prestart = 0.0
#         soft_limit_max = 10000000000.0
#         soft_limit_min = -10000000000.0
#         timeout = 10
#         tolerance = 0.0010000000474974513
#         value = float32(1442)
#       transmitting_material = 'Air'
#       type = 'radial'
#     flat_cone_angle:NXpositioner
#       master_value = float32(1442)
#       mu_x = float32(1442)
#       mu_y = float32(1442)
#       name = 'MUTILT'
#       offset = 0.0
#         @units = 'steps'
#       position_prestart = 3.350128736201441e-06
#         @units = 'degrees'
#       soft_limit_max = 360.0
#       soft_limit_min = -360.0
#       timeout = 300
#       tolerance = 0.10000000149011612
#       value = float32(1442)
#         @units = 'degrees'
#     instrument_responsible:NXuser
#       address = 'Hahn-Meitner Platz 1, D-14109 Berlin'
#       affiliation = 'Helmholtz Zentrum Berlin erstwhile HMI Berlin, Institute...'
#       email = 'hoffmann-j@helmholtz-berlin.de'
#       fax_number = '+49 30 8062 42999'
#       name = 'Dr. J.-U. Hoffmann'
#       role = 'Instrument Scientest'
#       telephone_number = '+49 30 8062 42185'
#     monochromator:NXcrystal
#       @target = '/entry_1/E2/monochromator'
#       monochromator_changer:NXpositioner
#         Cu_Monochromator:NXcrystal
#           type = 'Cu'
#         Ge_Monochromator:NXcrystal
#           type = 'Ge'
#           wavelength = 1.2100000381469727
#             @units = 'Angstroms'
#             @unitsdef = 'Angstroms = angstrom = decinanometer'
#         PG_Monochromator:NXcrystal
#           focusing:CARdirectory
#             motor_1:NXpositioner
#               master_value = float32(1442)
#               name = 'M1_FOC1'
#               offset = 0.0
#                 @units = 'steps'
#               position_prestart = 99.99999237060547
#                 @units = 'steps'
#               soft_limit_max = 110.0
#                 @units = 'steps'
#               soft_limit_min = -110.0
#                 @units = 'steps'
#               timeout = 10
#                 @units = 's'
#                 @unitsdef = 's = second'
#               tolerance = 0.10000000149011612
#                 @units = 'steps'
#               value = float32(1442)
#                 @units = 'steps'
#             motor_2:NXpositioner
#               master_value = float32(1442)
#               name = 'M1_FOC2'
#               offset = 0.0
#                 @units = 'steps'
#               position_prestart = 99.99999237060547
#                 @units = 'steps'
#               soft_limit_max = 110.0
#                 @units = 'steps'
#               soft_limit_min = -110.0
#                 @units = 'steps'
#               timeout = 10
#                 @units = 's'
#                 @unitsdef = 's = second'
#               tolerance = 0.10000000149011612
#                 @units = 'steps'
#               value = float32(1442)
#                 @units = 'steps'
#           type = 'PG'
#           wavelength = 2.390000104904175
#             @units = 'Angstroms'
#             @unitsdef = 'Angstroms = angstrom = decinanometer'
#         master_value = float32(1442)
#         name = 'MONOC'
#         offset = 0.0
#           @units = 'steps'
#         position_prestart = 124.99951171875
#           @units = 'steps'
#         soft_limit_max = 250.0
#         soft_limit_min = -200.0
#         timeout = 10
#           @units = 's'
#           @unitsdef = 's = second'
#         tolerance = 0.009999999776482582
#           @units = 'steps'
#         value = float32(1442)
#           @units = 'steps'
#       omega:NXpositioner
#         master_value = float32(1442)
#         name = 'OMGM'
#         offset = 0.0
#           @units = 'degrees'
#         position_prestart = 0.500244140625
#           @units = 'degrees'
#         soft_limit_max = 30.0
#         soft_limit_min = 0.0
#         timeout = 10
#         tolerance = 0.10000000149011612
#         value = float32(1442)
#       tilting:NXpositioner
#         master_value = float32(1442)
#         name = 'MONTI'
#         offset = 0.0
#           @units = 'steps'
#         position_prestart = 14.498779296875
#           @units = 'steps'
#         soft_limit_max = 20.0
#           @units = 'steps'
#         soft_limit_min = 0.5
#           @units = 'steps'
#         timeout = 10
#           @units = 's'
#           @unitsdef = 's = second'
#         tolerance = 0.10000000149011612
#           @units = 'steps'
#         value = float32(1442)
#           @units = 'steps'
#       translation:NXpositioner
#         master_value = float32(1442)
#         name = 'MONTR'
#         offset = 0.0
#           @units = 'steps'
#         position_prestart = 6.000244140625
#           @units = 'steps'
#         soft_limit_max = 15.0
#           @units = 'steps'
#         soft_limit_min = 1.0
#           @units = 'steps'
#         timeout = 10
#           @units = 's'
#           @unitsdef = 's = second'
#         tolerance = 0.10000000149011612
#           @units = 'steps'
#         value = float32(1442)
#           @units = 'steps'
#       wavelength = 1.2109999656677246
#         @units = 'Angstroms'
#     name = 'Flat-Cone-Diffractometer'
#       @short_name = 'E2'
#     premonochromator_collimator:NXcollimator
#       absorbing_material = 'GaO on a polymer foil'
#       blade_thickness = 0.20000000298023224
#         @units = 'mm'
#       collimator_changer:CARdirectory
#         COLL:NXpositioner
#           master_value = float32(1442)
#           name = 'COLL'
#           position_prestart = 30
#             @units = 'degrees'
#           timeout = 10
#           value = float32(1442)
#         collimator15_position:NXpositioner
#           master_value = float32(1442)
#           name = 'COLL15'
#           offset = 0.0
#             @units = 'steps'
#           position_prestart = 0.0
#             @units = 'procent'
#           soft_limit_max = 150.0
#           soft_limit_min = -150.0
#           timeout = 600
#             @units = 's'
#             @unitsdef = 's = second'
#           tolerance = 0.009999999776482582
#             @units = 'steps'
#           value = float32(1442)
#         collimator15_vertical:NXcollimator
#           absorbing_material = 'GaO on a polymer foil'
#           blade_spacing = 3.0
#             @units = 'mm'
#           blade_thickness = 0.20000000298023224
#             @units = 'mm'
#             @unitsdef = 'mm = 10E-3 meter'
#           soller_angle = 15.0
#             @units = 'arcmin'
#             @unitsdef = 'arcmin = arcminute'
#           tilting:NXpositioner
#             master_value = float32(1442)
#             name = 'COLL15T'
#             offset = 0.0
#               @units = 'steps'
#             position_prestart = -26.0
#               @units = 'steps'
#             soft_limit_max = 150.0
#             soft_limit_min = -150.0
#             timeout = 10
#               @units = 's'
#               @unitsdef = 's = second'
#             tolerance = 0.004999999888241291
#               @units = 'steps'
#             value = float32(1442)
#               @units = 'steps'
#           transmitting_material = 'air'
#           type = 'soller'
#         collimator30_position:NXpositioner
#           master_value = float32(1442)
#           name = 'COLL30'
#           offset = 0.0
#             @units = 'steps'
#           position_prestart = 100.21417236328125
#             @units = 'procent'
#           soft_limit_max = 150.0
#           soft_limit_min = -150.0
#           timeout = 600
#             @units = 's'
#             @unitsdef = 's = second'
#           tolerance = 0.009999999776482582
#             @units = 'steps'
#           value = float32(1442)
#         collimator30_vertical:NXcollimator
#           absorbing_material = 'GaO on a polymer foil'
#           blade_thickness = 0.20000000298023224
#             @units = 'mm'
#           soller_angle = 30.0
#             @units = 'arcmin'
#             @unitsdef = 'arcmin = arcminute'
#           tilting:NXpositioner
#             master_value = float32(1442)
#             name = 'COLL30T'
#             offset = 0.0
#               @units = 'steps'
#             position_prestart = -4.999975204467773
#               @units = 'steps'
#             soft_limit_max = 150.0
#             soft_limit_min = -150.0
#             timeout = 10
#               @units = 's'
#               @unitsdef = 's = second'
#             tolerance = 0.004999999888241291
#               @units = 'steps'
#             value = float32(1442)
#               @units = 'steps'
#           transmitting_material = 'air'
#           type = 'soller'
#         collimator_open_vertical:NXcollimator
#           absorbing_material = 'none'
#           blade_thickness = 0.0
#             @units = 'mm'
#             @unitsdef = 'mm = 1E-3 meter'
#           soller_angle = 60.0
#             @units = 'arcmin'
#             @unitsdef = 'arcmin = arcminute'
#           transmitting_material = 'air'
#           type = 'none'
#       set_soller_angle = float32(1442)
#         @units = 'minutes'
#       soller_angle = 30.0
#         @units = 'arcmin'
#         @unitsdef = 'arcmin = arcminute'
#       tilting:NXpositioner
#         master_value = float32(1442)
#         name = 'COLL30T'
#         offset = 0.0
#           @units = 'steps'
#         position_prestart = -4.999975204467773
#           @units = 'steps'
#         soft_limit_max = 150.0
#         soft_limit_min = -150.0
#         timeout = 10
#           @units = 's'
#           @unitsdef = 's = second'
#         tolerance = 0.004999999888241291
#           @units = 'steps'
#         value = float32(1442)
#           @units = 'steps'
#       transmitting_material = 'air'
#       type = 'soller'
#   caress:CARdirectory
#     BLS:CARdirectory
#       CHI1 = [-20.   20.5]
#         @nameDef = 'CHI1'
#       CHI2 = [-20.  20.]
#         @nameDef = 'CHI2'
#       COLL15 = [-150.  150.]
#         @nameDef = 'COLL15'
#       COLL15T = [-150.  150.]
#         @nameDef = 'COLL15T'
#       COLL30 = [-150.  150.]
#         @nameDef = 'COLL30'
#       COLL30T = [-150.  150.]
#         @nameDef = 'COLL30T'
#       HTRANS = [-150.  150.]
#         @nameDef = 'HTRANS'
#       M1_FOC1 = [-110.  110.]
#         @nameDef = 'M1_FOC1'
#       M1_FOC2 = [-110.  110.]
#         @nameDef = 'M1_FOC2'
#       MONOC = [-200.  250.]
#         @nameDef = 'MONOC'
#       MONTI = [ 0.5 20. ]
#         @nameDef = 'MONTI'
#       MONTR = [ 1. 15.]
#         @nameDef = 'MONTR'
#       MUTILT = [-360.  360.]
#         @nameDef = 'MUTILT'
#       OMGM = [ 0. 30.]
#         @nameDef = 'OMGM'
#       OMGR = [-110.  110.]
#         @nameDef = 'OMGR'
#       OMGS = [-360.  360.]
#         @nameDef = 'OMGS'
#       PHIS = [-360.  360.]
#         @nameDef = 'PHIS'
#       RADCOLL = [-1.e+10  1.e+10]
#         @nameDef = 'RADCOLL'
#       TEMP = [   0. 2000.]
#         @nameDef = 'TEMP'
#       TTH1 = [ 2.9 25.4]
#         @nameDef = 'TTH1'
#       TTH2 = [18.9 41.5]
#         @nameDef = 'TTH2'
#       TTH3 = [34.9 57.5]
#         @nameDef = 'TTH3'
#       TTH4 = [50.9 73.5]
#         @nameDef = 'TTH4'
#       TTHS = [-5. 25.]
#         @nameDef = 'TTHS'
#     PROT_BEG:CARdirectory
#       T_SAM = float32(1442)
#         @nameDef = 'T_SAM'
#     PROT_END:CARdirectory
#       T_SAM = float32(1442)
#         @nameDef = 'T_SAM'
#     READ:CARdirectory
#       CHI1 = 0.000247955322265625
#         @nameDef = 'CHI1'
#       CHI2 = 1.9073486328125e-06
#         @nameDef = 'CHI2'
#       COLL = 30
#         @nameDef = 'COLL'
#       COLL15 = 0.0
#         @nameDef = 'COLL15'
#       COLL15T = -26.0
#         @nameDef = 'COLL15T'
#       COLL30 = 100.21417236328125
#         @nameDef = 'COLL30'
#       COLL30T = -4.999975204467773
#         @nameDef = 'COLL30T'
#       HTRANS = -0.692307710647583
#         @nameDef = 'HTRANS'
#       M1_FOC1 = 99.99999237060547
#         @nameDef = 'M1_FOC1'
#       M1_FOC2 = 99.99999237060547
#         @nameDef = 'M1_FOC2'
#       MONOC = 124.99951171875
#         @nameDef = 'MONOC'
#       MONTI = 14.498779296875
#         @nameDef = 'MONTI'
#       MONTR = 6.000244140625
#         @nameDef = 'MONTR'
#       MUTILT = 3.350128736201441e-06
#         @nameDef = 'MUTILT'
#       MU_X = 0.038081806153059006
#         @nameDef = 'MU_X'
#       MU_Y = -0.05641748756170273
#         @nameDef = 'MU_Y'
#       OMGM = 0.500244140625
#         @nameDef = 'OMGM'
#       OMGR = 75.0
#         @nameDef = 'OMGR'
#       OMGS = 10.0
#         @nameDef = 'OMGS'
#       PHIS = -120.0
#         @nameDef = 'PHIS'
#       RADCOLL = 0.0
#         @nameDef = 'RADCOLL'
#       TEMP = float32(5)
#         @nameDef = 'TEMP'
#       TTH1 = 2.9994330406188965
#         @nameDef = 'TTH1'
#       TTH2 = 22.998010635375977
#         @nameDef = 'TTH2'
#       TTH3 = 42.998958587646484
#         @nameDef = 'TTH3'
#       TTH4 = 62.99848556518555
#         @nameDef = 'TTH4'
#       TTHS = 10.0
#         @nameDef = 'TTHS'
#       T_DELTA = 0.0
#         @nameDef = 'T_DELTA'
#       T_MEAN = 0.0
#         @nameDef = 'T_MEAN'
#       T_REG = 26.14150047302246
#         @nameDef = 'T_REG'
#       T_SAM = 0.0
#         @nameDef = 'T_SAM'
#       YSD = 163.3000030517578
#         @nameDef = 'YSD'
#     RELA:CARdirectory
#       NYS = [2.560e+02 7.500e+01 1.277e-01]
#         @nameDef = 'NYS'
#       TTHS = [2.560e+02 1.280e+02 1.277e-01]
#         @nameDef = 'TTHS'
#       YSD = 0.0
#         @nameDef = 'YSD'
#     SETV:CARdirectory
#       STEP = 0
#         @nameDef = 'STEP'
#     SETVALUE:CARdirectory
#       STEP = int32(1442)
#         @nameDef = 'STEP'
#       TEMP = float32(1442)
#         @nameDef = 'TEMP'
#     SOF:CARdirectory
#       CHI1 = 0.0
#         @nameDef = 'CHI1'
#       CHI2 = 0.0
#         @nameDef = 'CHI2'
#       COLL15 = 0.0
#         @nameDef = 'COLL15'
#       COLL15T = 0.0
#         @nameDef = 'COLL15T'
#       COLL30 = 0.0
#         @nameDef = 'COLL30'
#       COLL30T = 0.0
#         @nameDef = 'COLL30T'
#       HTRANS = 0.0
#         @nameDef = 'HTRANS'
#       M1_FOC1 = 0.0
#         @nameDef = 'M1_FOC1'
#       M1_FOC2 = 0.0
#         @nameDef = 'M1_FOC2'
#       MONOC = 0.0
#         @nameDef = 'MONOC'
#       MONTI = 0.0
#         @nameDef = 'MONTI'
#       MONTR = 0.0
#         @nameDef = 'MONTR'
#       MUTILT = 0.0
#         @nameDef = 'MUTILT'
#       OMGM = 0.0
#         @nameDef = 'OMGM'
#       OMGR = 0.0
#         @nameDef = 'OMGR'
#       OMGS = -2.5
#         @nameDef = 'OMGS'
#       PHIS = -19.0
#         @nameDef = 'PHIS'
#       RADCOLL = 0.0
#         @nameDef = 'RADCOLL'
#       TTH1 = -0.03999999910593033
#         @nameDef = 'TTH1'
#       TTH2 = -0.009999999776482582
#         @nameDef = 'TTH2'
#       TTH3 = -0.029999999329447746
#         @nameDef = 'TTH3'
#       TTH4 = -0.019999999552965164
#         @nameDef = 'TTH4'
#       TTHS = 0.0
#         @nameDef = 'TTHS'
#     TMO:CARdirectory
#       CHI1 = 10
#         @nameDef = 'CHI1'
#       CHI2 = 10
#         @nameDef = 'CHI2'
#       COLL = 10
#         @nameDef = 'COLL'
#       COLL15 = 600
#         @nameDef = 'COLL15'
#       COLL15T = 10
#         @nameDef = 'COLL15T'
#       COLL30 = 600
#         @nameDef = 'COLL30'
#       COLL30T = 10
#         @nameDef = 'COLL30T'
#       HTRANS = 10
#         @nameDef = 'HTRANS'
#       M1_FOC1 = 10
#         @nameDef = 'M1_FOC1'
#       M1_FOC2 = 10
#         @nameDef = 'M1_FOC2'
#       MONOC = 10
#         @nameDef = 'MONOC'
#       MONTI = 10
#         @nameDef = 'MONTI'
#       MONTR = 10
#         @nameDef = 'MONTR'
#       MUTILT = 300
#         @nameDef = 'MUTILT'
#       OMGM = 10
#         @nameDef = 'OMGM'
#       OMGR = 60
#         @nameDef = 'OMGR'
#       OMGS = 60
#         @nameDef = 'OMGS'
#       PHIS = 120
#         @nameDef = 'PHIS'
#       RADCOLL = 10
#         @nameDef = 'RADCOLL'
#       TEMP = 6
#         @nameDef = 'TEMP'
#       TTH1 = 300
#         @nameDef = 'TTH1'
#       TTH2 = 300
#         @nameDef = 'TTH2'
#       TTH3 = 300
#         @nameDef = 'TTH3'
#       TTH4 = 300
#         @nameDef = 'TTH4'
#       TTHS = 300
#         @nameDef = 'TTHS'
#     TOL:CARdirectory
#       CHI1 = 0.009999999776482582
#         @nameDef = 'CHI1'
#       CHI2 = 0.009999999776482582
#         @nameDef = 'CHI2'
#       COLL15 = 0.009999999776482582
#         @nameDef = 'COLL15'
#       COLL15T = 0.004999999888241291
#         @nameDef = 'COLL15T'
#       COLL30 = 0.009999999776482582
#         @nameDef = 'COLL30'
#       COLL30T = 0.004999999888241291
#         @nameDef = 'COLL30T'
#       HTRANS = 0.0010000000474974513
#         @nameDef = 'HTRANS'
#       M1_FOC1 = 0.10000000149011612
#         @nameDef = 'M1_FOC1'
#       M1_FOC2 = 0.10000000149011612
#         @nameDef = 'M1_FOC2'
#       MONOC = 0.009999999776482582
#         @nameDef = 'MONOC'
#       MONTI = 0.10000000149011612
#         @nameDef = 'MONTI'
#       MONTR = 0.10000000149011612
#         @nameDef = 'MONTR'
#       MUTILT = 0.10000000149011612
#         @nameDef = 'MUTILT'
#       OMGM = 0.10000000149011612
#         @nameDef = 'OMGM'
#       OMGR = 0.10000000149011612
#         @nameDef = 'OMGR'
#       OMGS = 0.019999999552965164
#         @nameDef = 'OMGS'
#       PHIS = 0.009999999776482582
#         @nameDef = 'PHIS'
#       RADCOLL = 0.0010000000474974513
#         @nameDef = 'RADCOLL'
#       TEMP = 0.10000000149011612
#         @nameDef = 'TEMP'
#       TTH1 = 0.009999999776482582
#         @nameDef = 'TTH1'
#       TTH2 = 0.009999999776482582
#         @nameDef = 'TTH2'
#       TTH3 = 0.009999999776482582
#         @nameDef = 'TTH3'
#       TTH4 = 0.009999999776482582
#         @nameDef = 'TTH4'
#       TTHS = 0.009999999776482582
#         @nameDef = 'TTHS'
#     WINDA:CARdirectory
#       W1 = int16(4)
#         @nameDef = 'W1'
#       W2 = int16(4)
#         @nameDef = 'W2'
#       W3 = int16(4)
#         @nameDef = 'W3'
#       W4 = int16(4)
#         @nameDef = 'W4'
#     corbadevice = '[MONOC]...'
#       @file = '/datacollector/data/E2/carconfig/corba_e209418.dat'
#       @format = 'text'
#       @source_name = 'Corbadevice'
#     date = '13-Dec-2012, 14-Dec-2012'
#     device_log = '# TIMESTAMP        RUN   STEP        MON       TIM1     ...'
#       @file = '/datacollector/data/E2/caress/e209418_device.dat'
#       @format = 'text'
#       @source_name = 'CARDEV'
#     hardware_modules = ';+++++++++++++++++++++++++++++++++++++++++++++++++++++++...'
#       @file = '/datacollector/data/E2/carconfig/hardware_e209...'
#       @format = 'text'
#       @source_name = 'Hardware_modules'
#     protocol = '/hmi/caress/data/e209418.dat...'
#       @file = '/datacollector/data/E2/prt/e209418.prt'
#       @format = 'text'
#       @source_name = 'CARPRT'
#     protocol_time = '2012-12-13 23:16:58 (info) created new protocol file...'
#       @file = '/datacollector/data/E2/caress/e209418.car.log'
#       @format = 'text'
#       @source_name = 'CARLOG'
#     steps:NXpositioner
#       name = 'STEP'
#       set_value = 0
#       target_value = int32(1442)
#       value = 0
#     time = '23:19:45, 10:29:56'
#     unused:CARdirectory
#       MSH = 0
#       MU_X:NXpositioner
#         master_value = float32(1442)
#         name = 'MU_X'
#         position_prestart = 0.038081806153059006
#           @units = 'degrees'
#         value = float32(1442)
#       MU_Y:NXpositioner
#         master_value = float32(1442)
#         name = 'MU_Y'
#         position_prestart = -0.05641748756170273
#           @units = 'degrees'
#         value = float32(1442)
#       W1 = int16(4)
#       W2 = int16(4)
#       W3 = int16(4)
#       W4 = int16(4)
#       YSD:NXpositioner
#         RELA = 0.0
#         master_value = float32(1442)
#         name = 'YSD'
#         position_prestart = 163.3000030517578
#           @units = 'degrees'
#         value = float32(1442)
#   caress_file = '/hmi/caress/data/e209418.dat'
#   datacollector:CARdirectory
#     commandline = '/datacollector/application/bin/main -son -v=4 -of=/datac...'
#     config_file = '/datacollector/application/configuration/E2_inst.xml'
#     protocol = 'LOG: Building dependency tree......'
#     source_file = '/datacollector/application/configuration/E2_src.xml'
#     start = '2012-12-14T10:29:57L'
#     stop = '2012-12-14T10:35:21L'
#     version = 'Datacollector V 2.03 Release $$Rev: 2177 $$'
#   end_time = '2012-12-14T10:29:56L'
#   entry_identifier = '/hmi/caress/data/e209418.dat'
#   experiment_type = 'E2, A2, ADET, FLAT, TEMP'
#   monitor:NXmonitor
#     MON:NXpositioner
#       MM1 = 14000
#       master_value = int32(1442)
#       name = 'MON'
#       value = int32(1442)
#     data = int32(1442)
#       @signal = '1'
#     mode = 'monitor'
#     preset = 14000
#     sampled_fraction = 0.009999999776482582
#       @units = 'counts'
#   notes = 'Overview Ge 30 chi1=chi2=mu=0'
#   powder_diagram:NXdata
#     data = float64(1801)
#     errors = float64(1801)
#     monitor_sum = float64(1801)
#     polar_angle = float64(1801)
#     referenz_monitor = 14000.007628294035
#     sum_raw_data = float64(1801)
#     x = float64(1801)
#   program_name = 'Datacollector'
#   protocol:NXprocess
#     caress_commentaries:NXnote
#       data = 'Overview Ge 30 chi1=chi2=mu=0'
#       type = 'text/plain'
#   reciprocal_space:NXdata
#     data = float64(500x500)
#     errors = float64(500x500)
#     monitor_sum = float64(500x500)
#     raw_data = float64(500x500)
#     reference_monitor = 14000.007628294035
#     x = float64(500)
#     y = float64(500)
#   run_cycle = 9418
#   run_number = 9418
#   sample:NXsample
#     beam:NXbeam
#       distance = 0.30000001192092896
#         @units = 'm'
#         @unitsdef = 'm = meter'
#       final_wavelength = 1.2109999656677246
#         @units = 'angstrom'
#         @unitsdef = 'angstrom = decinanometer'
#       monochromator:NXcrystal -> /entry_1/E2/monochromator
#         @target = '/entry_1/E2/monochromator'
#         monochromator_changer:NXpositioner
#           Cu_Monochromator:NXcrystal
#             type = 'Cu'
#           Ge_Monochromator:NXcrystal
#             type = 'Ge'
#             wavelength = 1.2100000381469727
#               @units = 'Angstroms'
#               @unitsdef = 'Angstroms = angstrom = decinanometer'
#           PG_Monochromator:NXcrystal
#             focusing:NXgroup
#               motor_1:NXpositioner
#                 master_value = float32(1442)
#                 name = 'M1_FOC1'
#                 offset = 0.0
#                   @units = 'steps'
#                 position_prestart = 99.99999237060547
#                   @units = 'steps'
#                 soft_limit_max = 110.0
#                   @units = 'steps'
#                 soft_limit_min = -110.0
#                   @units = 'steps'
#                 timeout = 10
#                   @units = 's'
#                   @unitsdef = 's = second'
#                 tolerance = 0.10000000149011612
#                   @units = 'steps'
#                 value = float32(1442)
#                   @units = 'steps'
#               motor_2:NXpositioner
#                 master_value = float32(1442)
#                 name = 'M1_FOC2'
#                 offset = 0.0
#                   @units = 'steps'
#                 position_prestart = 99.99999237060547
#                   @units = 'steps'
#                 soft_limit_max = 110.0
#                   @units = 'steps'
#                 soft_limit_min = -110.0
#                   @units = 'steps'
#                 timeout = 10
#                   @units = 's'
#                   @unitsdef = 's = second'
#                 tolerance = 0.10000000149011612
#                   @units = 'steps'
#                 value = float32(1442)
#                   @units = 'steps'
#             type = 'PG'
#             wavelength = 2.390000104904175
#               @units = 'Angstroms'
#               @unitsdef = 'Angstroms = angstrom = decinanometer'
#           master_value = float32(1442)
#           name = 'MONOC'
#           offset = 0.0
#             @units = 'steps'
#           position_prestart = 124.99951171875
#             @units = 'steps'
#           soft_limit_max = 250.0
#           soft_limit_min = -200.0
#           timeout = 10
#             @units = 's'
#             @unitsdef = 's = second'
#           tolerance = 0.009999999776482582
#             @units = 'steps'
#           value = float32(1442)
#             @units = 'steps'
#         omega:NXpositioner
#           master_value = float32(1442)
#           name = 'OMGM'
#           offset = 0.0
#             @units = 'degrees'
#           position_prestart = 0.500244140625
#             @units = 'degrees'
#           soft_limit_max = 30.0
#           soft_limit_min = 0.0
#           timeout = 10
#           tolerance = 0.10000000149011612
#           value = float32(1442)
#         tilting:NXpositioner
#           master_value = float32(1442)
#           name = 'MONTI'
#           offset = 0.0
#             @units = 'steps'
#           position_prestart = 14.498779296875
#             @units = 'steps'
#           soft_limit_max = 20.0
#             @units = 'steps'
#           soft_limit_min = 0.5
#             @units = 'steps'
#           timeout = 10
#             @units = 's'
#             @unitsdef = 's = second'
#           tolerance = 0.10000000149011612
#             @units = 'steps'
#           value = float32(1442)
#             @units = 'steps'
#         translation:NXpositioner
#           master_value = float32(1442)
#           name = 'MONTR'
#           offset = 0.0
#             @units = 'steps'
#           position_prestart = 6.000244140625
#             @units = 'steps'
#           soft_limit_max = 15.0
#             @units = 'steps'
#           soft_limit_min = 1.0
#             @units = 'steps'
#           timeout = 10
#             @units = 's'
#             @unitsdef = 's = second'
#           tolerance = 0.10000000149011612
#             @units = 'steps'
#           value = float32(1442)
#             @units = 'steps'
#         wavelength = 1.2109999656677246
#           @units = 'Angstroms'
#     chemical_formula = 'SAMPLE'
#     cross_cradle:CARcradle
#       CHI1:NXpositioner
#         master_value = float32(1442)
#         name = 'CHI1'
#         offset = 0.0
#           @units = 'degrees'
#         position_prestart = 0.000247955322265625
#           @units = 'degrees'
#         soft_limit_max = 20.5
#         soft_limit_min = -20.0
#         timeout = 10
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       CHI2:NXpositioner
#         master_value = float32(1442)
#         name = 'CHI2'
#         offset = 0.0
#           @units = 'degrees'
#         position_prestart = 1.9073486328125e-06
#           @units = 'degrees'
#         soft_limit_max = 20.0
#         soft_limit_min = -20.0
#         timeout = 10
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       OMGS:NXpositioner
#         master_value = float32(1442)
#         name = 'OMGS'
#         offset = -2.5
#           @units = 'degrees'
#         position_prestart = 10.0
#           @units = 'degrees'
#         soft_limit_max = 360.0
#         soft_limit_min = -360.0
#         timeout = 60
#         tolerance = 0.019999999552965164
#         value = float32(1442)
#       OMGX:NXpositioner
#         name = 'OMGX'
#       PHIS:NXpositioner
#         master_value = float32(1442)
#         name = 'PHIS'
#         offset = -19.0
#           @units = 'degrees'
#         position_prestart = -120.0
#           @units = 'degrees'
#         soft_limit_max = 360.0
#         soft_limit_min = -360.0
#         timeout = 120
#         tolerance = 0.009999999776482582
#         value = float32(1442)
#       chi_sample1 = float32(1442)
#         @lower_limit = -20.0
#         @name = 'CHI1'
#         @offset = 0.0
#         @timeout = 10
#         @tolerance = 0.009999999776482582
#         @units = 'degree'
#         @unitsdef = 'degree = angular_degree'
#         @upper_limit = 20.5
#       chi_sample2 = float32(1442)
#         @lower_limit = -20.0
#         @name = 'CHI2'
#         @offset = 0.0
#         @timeout = 10
#         @tolerance = 0.009999999776482582
#         @units = 'degree'
#         @unitsdef = 'degree = angular_degree'
#         @upper_limit = 20.0
#       name = 'Standard E2'
#       omega_sample = float32(1442)
#         @lower_limit = -360.0
#         @name = 'OMGS'
#         @offset = -2.5
#         @timeout = 60
#         @tolerance = 0.019999999552965164
#         @units = 'degree'
#         @unitsdef = 'degree = angular_degree'
#         @upper_limit = 360.0
#       phi_sample = float32(1442)
#         @lower_limit = -360.0
#         @name = 'PHIS'
#         @offset = 0.0
#         @timeout = 120
#         @tolerance = 0.009999999776482582
#         @units = 'degree'
#         @unitsdef = 'degree = angular_degree'
#         @upper_limit = 360.0
#       type = 'cross'
#     hkl:CARdirectory
#       E:NXpositioner
#         name = 'E'
#       h:NXpositioner
#         name = 'H'
#       k:NXpositioner
#         name = 'K'
#       l:NXpositioner
#         name = 'L'
#     name = 'SAMPLE'
#     orientation_matrix = float32(9)
#     rotation_angle = float64(1442)
#       @name = 'entry_1/sample/cross_cradle/phi_sample'
#       @units = 'degree'
#       @unitsdef = 'degree = angular_degree'
#     sample_environment_control:CARdirectory
#       COLDTRAP:NXpositioner
#         name = 'COLDTRAP'
#       HE:NXpositioner
#         name = 'HE'
#       LN2:NXpositioner
#         name = 'LN2'
#       MAGF:NXpositioner
#         name = 'MAGF'
#       TEMP:NXpositioner
#         name = 'TEMP'
#         position_prestart = float32(5)
#           @units = 'degrees'
#         soft_limit_max = 2000.0
#         soft_limit_min = 0.0
#         target_value = float32(1442)
#         timeout = 6
#         tolerance = 0.10000000149011612
#       T_DELTA:NXpositioner
#         master_value = float32(1442)
#         name = 'T_DELTA'
#         position_prestart = 0.0
#           @units = 'degrees'
#         value = float32(1442)
#       T_MEAN:NXpositioner
#         master_value = float32(1442)
#         name = 'T_MEAN'
#         position_prestart = 0.0
#           @units = 'degrees'
#         value = float32(1442)
#       T_REG:NXpositioner
#         master_value = float32(1442)
#         name = 'T_REG'
#         position_prestart = 26.14150047302246
#           @units = 'degrees'
#         value = float32(1442)
#       T_SAM:NXpositioner
#         name = 'T_SAM'
#         position_prestart = 0.0
#           @units = 'degrees'
#         protocol_value_begin = float32(1442)
#         protocol_value_end = float32(1442)
#         value = float32(1442)
#       delta_temperature = float32(1442)
#         @units = 'kelvin'
#         @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#       mean_temperature = float32(1442)
#         @units = 'kelvin'
#         @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#       regulation_temperature = float32(1442)
#         @units = 'kelvin'
#         @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#       sample_temperature = float32(1442)
#         @units = 'kelvin'
#         @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#     sample_environment_group:NXuser
#       address = 'Glienicker Str. 100, D-14109 Berlin'
#       affiliation = 'HMI Berlin'
#       email = 'michael.meissner@hmi.de'
#       name = 'Prof. Dr. Michael Meissner'
#       role = 'Group Leader  Sample Environment'
#       telephone_number = '+49 30 8062 2204'
#     temperature = float32(1442)
#       @units = 'kelvin'
#       @unitsdef = 'degree_Celsius = kelvin @ 273.15'
#     unit_cell = float32(6)
#       @units = 'angstrom and degree'
#       @unitsdef = 'angstrom = decinanometer    and   degree = ang...'
#   start_time = '2012-12-13T23:19:45L'
#   step_number = 0
#   timer:NXmonitor
#     TIM1:NXpositioner
#       master_value = int32(1442)
#       name = 'TIM1'
#       value = int32(1442)
#     TIM2:NXpositioner
#       master_value = int32(1442)
#       name = 'TIM2'
#       value = int32(1442)
#     backup:NXmonitor
#       data = int32(1442)
#       mode = 'timer'
#     data = int32(1442)
#       @signal = '1'
#     mode = 'timer'
#   title = 'D2O SC CC PHY-01-2836-EF'
#   user_caress:NXuser
#     name = 'Klemke'
#     role = 'Caress Main User'

# %%
print(a.entry_1.sample.beam.monochromator.keys())
# Out:
# dict_keys(['monochromator_changer', 'omega', 'tilting', 'translation', 'wavelength'])

# %% [markdown]
# In NeXus files is possible to create links to other elements of the structure or to external files

# %%
print(a.entry_1.datacollector.config_file)
# Out:
# /datacollector/application/configuration/E2_inst.xml

# %% [markdown]
# # 2. Identify fields, groups and NXdata group

# %%
a['entry_1/E2']
# Out:
# NXinstrument('E2')

# %% [markdown]
# NXinstrument include a collection of the instrument or beamline components

# %%
a['entry_1']
# Out:
# NXentry('entry_1')

# %% [markdown]
# NXentry describes the measurements

# %%
a['entry_1/sample']
# Out:
# NXsample('sample')

# %% [markdown]
# NXsample contains the sample description

# %%
a['entry_1/caress']
# Out:
# NXgroup('caress')

# %%
a['entry_1/E2/monochromator']
# Out:
# NXcrystal('monochromator')

# %% [markdown]
# Further reading at https://manual.nexusformat.org/classes/index.html
#
# https://manual.nexusformat.org/classes/base_classes/index.html#base-class-definitions

# %% [markdown]
# # 3. Data visualization

# %% [markdown]
# Further data visualization and processing can be done in:
#
#     NexPy
#
#     hdfview
#
#     Dawn www.dawnsci.org
#
#     Matlab www.matworks.com;
#            https://manual.nexusformat.org/examples/matlab/index.html

# %% [markdown]
# # 4. Data manipulation

# %% [markdown]
# Array operation, similarly with NumPy array can be done with NXdata groups and NXfields (array +metadata)
#
# It is possible to add an image to the NeXus files
#
# https://manual.nexusformat.org/examples/epics/index.html

# %% [markdown]
# # 5. Format conversion of the metadata

# %% [markdown]
# The metadata structure can be converted to an xml file or json dictionary.
#
# It is always possible to save the array of data in ascii
# NeXus-JSON
# https://github.com/ess-dmsc/nexus-json
#
# or using nxconvert from nexusformat project

# %% [markdown]
# # 7. Nexus files archiving

# %% [markdown]
# # 6. Nexus files validator

# %%
NXarchive is an application for data to be archived in ICAT
it calls the groups
NXentry, NXinstrument, NXsample, NXsource, NXuser

# %%
punx validate ./filename
